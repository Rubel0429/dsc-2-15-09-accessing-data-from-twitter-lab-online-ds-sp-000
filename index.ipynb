# %% [markdown]
# # Data mining with Twitter API and Basic NLP - Lab
#
# ## Introduction
# In this lab, we shall use our Twitter developer account created in the previous lessson and the keys we generated to make some API calls to twitter. We shall look at a number of ways of accessing twitter data which may suit different use cases for twitter API calling. We shall also get an introduction to the `tweepy` Python library to help us with tweet mining and parsing. We shall perform some basic NLP to count the term frequencies etc.
#
# **Note:** You are encourages to consult the Twitter API documentation and `tweepy` library documentation to understand structure of tweets and their properties for accessing specific elements.
#
#
# ## Objectives
#
# You will be able to:
# * Successfully request tweet data from the Twitter API using the Tweepy library
# * Understand the structure of Twitter JSON object structure
# * Parse tweet data and perform basic text analysis using basic NLP techniques
# * Visualize hashtags, mentions from tweets using number of visualization techniques
# * Collect and Parse tweets for a number of use cases

# %% [markdown]
# ## `tweepy`
#
# Tweepy is open-source library, hosted on GitHub and enables Python to communicate with Twitter platform and use its API. Remember , we can access Twitter API and access tweets even without this library. Tweepy makes the whole process simple and easy to understand and execute. Visit [HERE](https://pythonhosted.org/tweepy/index.html) for Tweepy's official documentation and a full list of offered features.
#
# Installing tweepy is easy, it can be pip installed as shown below:

# %%
# uncomment and pip install tweepy if you havent done so already
# !pip install tweepy
# Out:
# Requirement already satisfied: tweepy in c:\users\rrubel\appdata\local\continuum\anaconda3\lib\site-packages (3.7.0)
# Requirement already satisfied: six>=1.10.0 in c:\users\rrubel\appdata\local\continuum\anaconda3\lib\site-packages (from tweepy) (1.11.0)
# Requirement already satisfied: PySocks>=1.5.7 in c:\users\rrubel\appdata\local\continuum\anaconda3\lib\site-packages (from tweepy) (1.6.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\rrubel\appdata\local\continuum\anaconda3\lib\site-packages (from tweepy) (1.0.0)
# Requirement already satisfied: requests>=2.11.1 in c:\users\rrubel\appdata\local\continuum\anaconda3\lib\site-packages (from tweepy) (2.19.1)
# Requirement already satisfied: oauthlib>=0.6.2 in c:\users\rrubel\appdata\local\continuum\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->tweepy) (2.1.0)
# Requirement already satisfied: urllib3<1.24,>=1.21.1 in c:\users\rrubel\appdata\local\continuum\anaconda3\lib\site-packages (from requests>=2.11.1->tweepy) (1.23)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\rrubel\appdata\local\continuum\anaconda3\lib\site-packages (from requests>=2.11.1->tweepy) (3.0.4)
# Requirement already satisfied: idna<2.8,>=2.5 in c:\users\rrubel\appdata\local\continuum\anaconda3\lib\site-packages (from requests>=2.11.1->tweepy) (2.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\rrubel\appdata\local\continuum\anaconda3\lib\site-packages (from requests>=2.11.1->tweepy) (2018.8.24)

# %% [markdown]
# We can now simply import import tweepy in the python working environment

# %%
# Import tweepy
import tweepy

import operator 
import json
from collections import Counter
import pandas as pd
from nltk import bigrams

# %% [markdown]
# So we are now good to move on with setting up tweepy with our user and access tokens.
#
# ### Using tweepy
# Tweepy supports accessing Twitter through OAuth. Twitter has stopped accepting Basic Authentication so OAuth is now the only way to use the Twitter API. In order to create the API object, however, we must first authenticate ourselves with our developer information.
# * Enter your credentials into access_token, access_token_secret, consumer_key, and consumer_secret below

# %%
# Set credential variables with appropriate string values
consumer_key = "ReEXaG7QO5HrssvArTNFomj9a"
consumer_secret = "MxYyIj4h6LXpccdYkOXdj1uVgJHIIHArpBczTDwANE6PXmXi3i"
access_token = "1077042819699748865-1snkQXZbloavoL4xmTC3XccomKyyox"
access_token_secret = "WoTSYZ1nJK82xoJAiRdLX7FjhsVK14CSD9WDRRsfLDoSo"

# %% [markdown]
# ### Create the Authentication Object
#
# Our next step would be to create tweepy  OAuthHandler instance with our consumer key and secret and set access token and secret using `tweepy.set_access_token`. We can then create an API object with this information.
#
# We shall set it up as shown below:
#
# ```python
# # Create the tweepy authentication object with consumer key and secret
# auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
# # Setting your access token and secret
# auth.set_access_token(access_token, access_token_secret)
# # Creating the API object while passing in auth information
# my_first_api = tweepy.API(auth)
# ```

# %%
# Paste above code here with your credentials to create the Oauth Handler Instance and API object
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
my_first_api = tweepy.API(auth)

# %% [markdown]
# If the above cell executed without any error.. congratulations. You can now start mining the Twitter API through `my_first_api` object.
#
# NOTE: If you have a web application and are using a callback URL that needs to be supplied dynamically, you would pass it in like shown below:
# ```python
# auth = tweepy.OAuthHandler(consumer_token, consumer_secret, callback_url)
# ```

# %% [markdown]
# ## Collecting Tweets From Own Timeline - `home_timeline()` method
# A detailed indsight into Tweepy's API object with supported methods to post, retrieve and select tweets can be found at [Tweepy's API Dcoumentation](https://pythonhosted.org/tweepy/api.html#api-reference). It is strongly recommended for you to visit the documentation and study all the relevant methods and arguments that they take.
#
# We can directly collect tweets from our home timeline by applying the method `api.home_timeline()`, which collects 20 most recent tweets by default (including retweeted tweets). To adjust the desired number of tweets (take 100 tweets for example),  we can pass in a parameter value as (count = 100).
#
# By default we get first 140 characters of a tweet. We can, however, optionally pass in an extra argument `tweet_mode='extended'` to get the full length of the tweet. This might be useful if you are interested in analyzing the full text of tweets rather than geographical locations, and hashtags etc. only.
#
# Perform the following
# * See how to get extended tweets [Here](https://github.com/sferik/twitter/issues/880). Use the API object to get tweets from your timeline ,collect 500 tweets.
# * Save the results into `my_timeline_tweets`.

# %%
# Store the tweets it in a variable called my_timeline_tweets

my_timeline_tweets = my_first_api.home_timeline(count=500, tweet_mode="extended")

# %% [markdown]
# ### Tweet JSON
#
# All Twitter APIs that return Tweets provide that data encoded using JavaScript Object Notation (JSON). Here is a summary of information you may find in a typical Tweet JASON.
#
# * Each Tweet has an **author**, a **message**, a **unique ID**, a **timestamp** of when it was posted.
# * Some tweets contain **geo metadata** shared by the user.
# * Each User has a Twitter **name**, an **ID**, a **number of followers**, and most often an account **bio**.
# * With each Tweet we also get **"entity"** objects, which are arrays of common Tweet contents such as **hashtags**, **mentions**, **media**, and **links**.
# * If there are links, the JSON payload can also provide metadata such as the fully unwound **URL** and the webpage’s **title** and **description**.
#
# You may not need all this information for every experiment, but its a good idea to have a general understanding of what data we receive as the result of our API call.
#
# Here is what a Tweet JSON structure looks like:
#
# ---
#
# ```pythpn
# {
#   "created_at": "Thu Apr 06 15:24:15 +0000 2017",
#   "id_str": "850006245121695744",
#   "text": "1\/ Today we\u2019re sharing our vision for the future of the Twitter API platform!\nhttps:\/\/t.co\/XweGngmxlP",
#   "user": {
#     "id": 2244994945,
#     "name": "Twitter Dev",
#     "screen_name": "TwitterDev",
#     "location": "Internet",
#     "url": "https:\/\/dev.twitter.com\/",
#     "description": "Your official source for Twitter Platform news, updates & events. Need technical help? Visit https:\/\/twittercommunity.com\/ \u2328\ufe0f #TapIntoTwitter"
#   },
#   "place": {
#   },
#   "entities": {
#     "hashtags": [
#     ],
#     "urls": [
#       {
#         "url": "https:\/\/t.co\/XweGngmxlP",
#         "unwound": {
#           "url": "https:\/\/cards.twitter.com\/cards\/18ce53wgo4h\/3xo1c",
#           "title": "Building the Future of the Twitter API Platform"
#         }
#       }
#     ],
#     "user_mentions": [
#     ]
#   }
# }
#
#
#
# ```
#
# ---

# %% [markdown]
# ## Parsing Tweet JSON
#
# Let's try to print a single tweet to see what it looks like

# %%
# Unomment below to view contents of the tweet
my_timeline_tweets[0]
# Out:
# Status(_api=<tweepy.api.API object at 0x000001DA3A2C9F28>, _json={'created_at': 'Fri Dec 28 16:15:00 +0000 2018', 'id': 1078685757785559040, 'id_str': '1078685757785559040', 'full_text': 'J and Z Customers: from 9:30 PM 12/28, until 5AM 1/7, J trains will not run between Jamaica Center and 121 St while we rebuild a section of track in Queens. Details: https://t.co/PABjqAJwbH https://t.co/Q63O1kWNVR', 'truncated': False, 'display_text_range': [0, 189], 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/PABjqAJwbH', 'expanded_url': 'http://web.mta.info/nyct/service/serviceChange/jz.html', 'display_url': 'web.mta.info/nyct/service/s…', 'indices': [166, 189]}], 'media': [{'id': 1078286499655880704, 'id_str': '1078286499655880704', 'indices': [190, 213], 'media_url': 'http://pbs.twimg.com/media/DvbX28IWkAAjoyw.jpg', 'media_url_https': 'https://pbs.twimg.com/media/DvbX28IWkAAjoyw.jpg', 'url': 'https://t.co/Q63O1kWNVR', 'display_url': 'pic.twitter.com/Q63O1kWNVR', 'expanded_url': 'https://twitter.com/NYCTSubway/status/1078685757785559040/photo/1', 'type': 'photo', 'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'large': {'w': 1920, 'h': 1080, 'resize': 'fit'}, 'medium': {'w': 1200, 'h': 675, 'resize': 'fit'}, 'small': {'w': 680, 'h': 383, 'resize': 'fit'}}}]}, 'extended_entities': {'media': [{'id': 1078286499655880704, 'id_str': '1078286499655880704', 'indices': [190, 213], 'media_url': 'http://pbs.twimg.com/media/DvbX28IWkAAjoyw.jpg', 'media_url_https': 'https://pbs.twimg.com/media/DvbX28IWkAAjoyw.jpg', 'url': 'https://t.co/Q63O1kWNVR', 'display_url': 'pic.twitter.com/Q63O1kWNVR', 'expanded_url': 'https://twitter.com/NYCTSubway/status/1078685757785559040/photo/1', 'type': 'photo', 'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'large': {'w': 1920, 'h': 1080, 'resize': 'fit'}, 'medium': {'w': 1200, 'h': 675, 'resize': 'fit'}, 'small': {'w': 680, 'h': 383, 'resize': 'fit'}}}]}, 'source': '<a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 66379182, 'id_str': '66379182', 'name': 'NYCT Subway', 'screen_name': 'NYCTSubway', 'location': 'New York City', 'description': 'Official source for news and service change information for MTA NYC Transit subway service. Monitored 24/7. Emergency call 911.', 'url': 'https://t.co/A32pJWLkKU', 'entities': {'url': {'urls': [{'url': 'https://t.co/A32pJWLkKU', 'expanded_url': 'http://www.mta.info', 'display_url': 'mta.info', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 960221, 'friends_count': 301, 'listed_count': 4087, 'created_at': 'Mon Aug 17 15:28:03 +0000 2009', 'favourites_count': 1507, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': True, 'statuses_count': 340614, 'lang': 'en', 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': '000000', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/902288411280760832/IU1D9DJd_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/902288411280760832/IU1D9DJd_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/66379182/1525279294', 'profile_link_color': '000003', 'profile_sidebar_border_color': 'FFFFFF', 'profile_sidebar_fill_color': 'F0D108', 'profile_text_color': '0A070F', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': False, 'default_profile_image': False, 'following': True, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'},  ...

# %% [markdown]
# So the Tweet here is in the JSON format , which we can parse as dictionaries.
#
# We can iterate through collected tweets in `my_timeline_tweets` to access any of the properties of each tweet. Let's print the name and location of users with `.user.name`, `.user.locations` propoerties, and content of the each tweet using the `.text` property.
#
# **NOTE:** Use `.full_text` in case of using `tweet_mode='extended'` OR just `.text` if you havent passed in the extended argument.
#
# #### Iterate through `my_timeline_tweets` and print the usernames, location and text of the each collected tweet.

# %%
# Iterate through my_timeline_tweets and print the name, location and text for each tweet using k:v pairs addressing
for i in list(range(0,len(my_timeline_tweets))):
    
    print(my_timeline_tweets[i].user.name)
    print(my_timeline_tweets[i].user.location)
    print(my_timeline_tweets[i].full_text)
    print("_____________________________________")

# EXAMPLE OUTPUT
    
# Dr. Data&Science 🎃
# SFO | ATL | 🛫
# RT @RalstonReports: The turnout models are looking better for Democrats in Nevada as they boost their statewide lead a bit, but long way to…
# ----------------------------------------------------------------------------
# Data Science Central
# Seattle, WA
# [Cheat Sheet] Python Basics For Data Science https://t.co/fH07ZFF9zw
# ----------------------------------------------------------------------------
# Dr. Data&Science 🎃
# SFO | ATL | 🛫
# RT @Popehat: NYT:  Well, Okay, But Are People Mean To Trump?
# Everyone: Can you not
# NYT:  Jazz: What If Black People Got Involved In Jazz
# Ev…
# .
# .
# .
# .
# IBM Data Science
# San Francisco, CA
# Essential math for data science: A curated list including functions, variables, equations, graphs, statistics, linear algebra, calculus, discrete math, optimization, and operation research topics, whew. Check it out here: https://t.co/0JtcPuJ04N via @kdnuggets #datascience https://t.co/E2m2trORG9
# ----------------------------------------------------------------------------
# Data Science Central
# Los Angeles, CA
# The Mathematics of Machine Learning https://t.co/GUBZVT8NUj
# Out:
# NYCT Subway
# New York City
# J and Z Customers: from 9:30 PM 12/28, until 5AM 1/7, J trains will not run between Jamaica Center and 121 St while we rebuild a section of track in Queens. Details: https://t.co/PABjqAJwbH https://t.co/Q63O1kWNVR
# _____________________________________
# Flatiron School
# New York, NY
# Make 2019 your best year yet. Here are 19 reasons why learning code should be on your New Year's resolutions list https://t.co/vTHbZ558Ux https://t.co/1ZMwugpqjE
# _____________________________________
# City of New York
# New York City
# RT @NWSNewYorkNY: Widespread rain has moved in and this rain will continue through much of today. Some occasional heavy rain will be possib…
# _____________________________________
# NYCT Subway
# New York City
# Southbound 3 trains have resumed making all regular stops after we corrected a signal problem at New Lots Av.
# https://t.co/SrIf9RnUgM
# _____________________________________
# NYCT Subway
# New York City
# Northbound 1 trains have resumed making local stops from 96 St to 137 St-City College after earlier NYPD activity at 103 St.
#
# Expect residual delays on northbound 1, 2 and 3 trains as service normalizes.
#
# https://t.co/3dLsonZYwI
# _____________________________________
# City of New York
# New York City
# The most important issue facing New York is ___________. Take the 2-min #OneNYC survey and make your voice heard. https://t.co/vtdrLO6bJN @NYClimate https://t.co/QbwD00bZ5j
# _____________________________________
# NYCT Subway
# New York City
# Northbound 1 trains are making express stops from 96 St to 137 St-City College because of NYPD activity at 103 St.
#
# Expect delays on northbound 1, 2 and 3 trains.
# _____________________________________
# NYCT Subway
# New York City
# Some southbound 3 trains will end at Crown Hts-Utica Av or Junius St because of a signal problem at New Lots Av.
#
# Southbound 2 and 3 trains are running with delays while we work to repair the signal problem.
#
# https://t.co/SrIf9RnUgM
# _____________________________________
# NYCT Subway
# New York City
# Some southbound 3 trains will end at Crown Hts-Utica Av or Junius St because of a signal problem at New Lots Av.
# _____________________________________
# City of New York
# New York City
# Clean, non-bagged Christmas trees left on the curb between Wednesday, January 2 and Saturday, January 12, will be chipped, mixed with leaves, and recycled into compost for the city’s parks, institutions and community gardens. https://t.co/lkyiPX1doP via @NYCSanitation
# _____________________________________
# NYCT Subway
# New York City
# Some southbound F trains are running on the E line from Jackson Hts-Roosevelt Av to Queens Plaza, then via the G line from Queens Plaza to Bergen St because of congestion in Manhattan.
# _____________________________________
# City of New York
# New York City
# RT @NYCMayorsOffice: New Yorkers are tough, but their umbrellas... less so. The high will be 58 degrees with rain throughout the day, and t…
# _____________________________________
# City of New York
# New York City
# Have electronic devices and/or appliances that need to be thrown out and recycled? @NYCSanitation is doing requests for curbside E-Waste pickup for Staten Island, Western Queens and Brooklyn. Find the form here: https://t.co/eS7aO8J6JW https://t.co/SXGtSgjWCK
# _____________________________________
# NYCT Subway
# New York City
# Southbound F trains are delayed because of a signal malfunction at Avenue N.
# _____________________________________
# NYCT Subway
# New York City
# Southbound 4 and 5 trains are now moving again after we removed a train with mechanical problems from service at Bowling Green.
#
# https://t.co/dw2BVPvKic
# _____________________________________
# NYCT Subway
# New York City
# Southbound 4 and 5 trains are delayed while we remove a train with mechanical problems from service at Bowling Green.
# _____________________________________
# NYCT Subway
# New York City
# Southbound Q train service has resumed after earlier NYPD activity at 57 St-7 Av. https://t.co/hatsAyg1Ki
# _____________________________________
# NYCT Subway
# New York City
# Southbound Q trains are running with delays because of NYPD activity at 57 St-7 Av.
# _____________________________________
# NYCT Subway
# New York City
# Southbound 4 local service has resumed from Burnside Av to 149 St-Grand Concourse after we moved a train that had its brakes activated at 167 St. https://t.co/u48X1t525Y
# _____________________________________
# NYCT Subway
# New York City
# L trains are no longer delayed after we moved overnight work trains to the storage facility. https://t.co/ucF03xqm3N
# _____________________________________
# NYCT Subway
# New York City
# Southbound 4 trains are running express from Burnside Av to 149 St-Grand Concourse because a train's brakes were automatically activated at 167 St.
# _____________________________________
# NYCT Subway
# New York City
# L trains are running with delays in both directions while we move overnight work trains to the storage facility.
# _____________________________________
# NYCT Subway
# New York City
# 8 Av-bound L trains have resumed stopping at 8 Av-bound platforms from Bedford Av to 3 Av after we moved an earlier stalled overnight work train near Bedford Av. https://t.co/0rZtdhU83C
# _____________________________________
# NYCT Subway
# New York City
# 8 Av-bound L trains are stopping at the Canarsie-bound platforms at Bedford Av, 3 Av &amp; 1 Av while overnight work trains return to the storage yard.
#
# As an alternative, for service between Brooklyn and Manhattan, consider taking A, C, J, and M trains.
# _____________________________________
# NYCT Subway
# New York City
# Northbound N and Q trains have resumed local stops from Canal St to 34 St-Herald Square after earlier signal problems at 23 St. https://t.co/i4mEL4DpPy
# _____________________________________
# NYCT Subway
# New York City
# Service Update: Northbound N and Q trains are running express from Canal St to 34 St-Herald Square because of signal problems at 23 St.
# For bypassed stations, take a southbound N or Q train. https://t.co/RPsqZzAboX
# _____________________________________
# NYCT Subway
# New York City
# Southbound 4 and 6 trains are now proceeding at Fulton St after earlier NYPD activity. https://t.co/nx73qfZcSl
# _____________________________________
# NYCT Subway
# New York City
# Northbound N and Q trains are running with delays because of signal problems at 23 St.
# _____________________________________
# NYCT Subway
# New York City
# Northbound 4 and 6 trains are now proceeding after earlier temporary track maintenance at Grand Central-42 St. https://t.co/GMZk9xVu7c
# _____________________________________
# NYCT Subway
# New York City
# 1, 2, and 3 trains are no longer delayed after our crews performed temporary track maintenance at Central Park North (110 St). https://t.co/PKeitMd3xD
# _____________________________________
# NYCT Subway
# New York City
# Southbound 4 and 6 trains are delayed because of NYPD activity at Fulton St.
# _____________________________________
# NYCT Subway
# New York City
# Northbound 4 and 6 trains are delayed while our crews perform temporary track maintenance at Grand Central-42 St.
# _____________________________________
# NYCT Subway
# New York City
# Service update: 1, 2, and 3 trains are delayed in both directions because of temporary track maintenance at Central Park North (110 St).
# _____________________________________
# NYCT Subway
# New York City
# 2 and 3 trains are delayed in both directions because of temporary track maintenance at Central Park North (110 St).
# _____________________________________
# NYCT Subway
# New York City
# Northbound 4 trains are proceeding with delays after we removed a train from service at 149 St-Grand Concourse. https://t.co/BEICmJ4P4u
# _____________________________________
# NYCT Subway
# New York City
# Northbound 4 trains are delayed while we remove a train with a mechanical problem from service at 149 St-Grand Concourse.
# _____________________________________
# NYCT Subway
# New York City
# 7 trains are no longer delayed after an earlier Con Edison explosion in Queens. #bluesky https://t.co/fneUTXwpTr
# _____________________________________
# City of New York
# New York City
# RT @NYPD114Pct: Transformer explosion was determined to be a non-suspicious equipment malfunction. Please continue to avoid the area due to…
# _____________________________________
# City of New York
# New York City
# RT @ConEdison: There was a brief electrical fire at our substation on 20th Avenue &amp; 32nd Street in Astoria this evening, which caused a tra…
# _____________________________________
# NYCT Subway
# New York City
# Northbound D trains are proceeding with delays after we corrected a door problem on a train at 125 St. https://t.co/DvfiWfiEAQ
# _____________________________________
# City of New York
# New York City
# RT @nycgob: — Ya está regresando la luz en el aeropuerto de La Guardia, pero se esperan retrasos
#
# — Con Ed está evaluando cortes eléctricos…
# _____________________________________
# City of New York
# New York City
# RT @nycgob: Lo que sabemos:
#
# — La luz que se vio fue causada por una descarga eléctrica.
#
# — No hay incendios en este momento, ni heridos.…
# _____________________________________
# NYCT Subway
# New York City
# Northbound D trains are delayed because of a train with a door problem at 125 St.
# _____________________________________
# City of New York
# New York City
# RT @NYPDnews: Confirming incident in #Astoria was result of transformer explosion. No injuries, no fire, no evidence of extraterrestrial ac…
# _____________________________________
# NYCT Subway
# New York City
# For service between 74 St-Broadway and Main St-Flushing Av, consider nearby Q66 bus service.
#
# For service between 111 St and Main St-Flushing Av, consider nearby Q48 bus service.
#
# Use the MTA BusTime app to check bus arrival times.
# _____________________________________
# NYCT Subway
# New York City
# For service between 34 St-Hudson Yards and 74 St-Broadway, consider using nearby E, F, and R train service.
# _____________________________________
# NYCT Subway
# New York City
# Coney Island-bound D trains have resumed scheduled stops from 36 St to Coney Island-Stillwell Ave after an earlier train's brakes were activated.
# https://t.co/LhqJ9vnqS6
# _____________________________________
# NYCT Subway
# New York City
# Southbound 2 trains have resumed making all stops from E 180 St to 3 Av-149 St after we moved a train that had its brakes activated at Simpson St. https://t.co/UEqOulK3PO
# _____________________________________
# NYCT Subway
# New York City
# There are extensive delays in 7 train service in both directions because of an earlier Con Edison explosion in Queens.
#
# For service between 34 St-Hudson Yards and 74 St-Broadway, consider using nearby E, F, and R train service.
# _____________________________________
# City of New York
# New York City
# RT @ConEdison: There was a brief electrical fire at our substation in Astoria which involved some electrical transformers and caused a tran…
# _____________________________________
# NYCT Subway
# New York City
# Coney Island-bound D trains are running on the N line from 36 St to Coney Island-Stillwell Av because a train's brakes were activated at Coney Island-Stillwell Av.
#
# For service to bypassed stations, transfer to a Bronx-bound D train at Coney Island-Stillwell Av.
# _____________________________________
# City of New York
# New York City
# RT @LGAairport: Due to a power outage in Queens, there is partial flight operations @LGAairport. Many flights are departing, some are not.…
# _____________________________________
# NYCT Subway
# New York City
# Southbound 2 trains are making express stops from E 180 St to 3 Av-149 St because a train's brakes were activated at Simpson St and we are investigating.
# _____________________________________
# City of New York
# New York City
# RT @NYCMayor: What we know:
#
# - Light was caused by electrical surge at a substation.
#
# - No current fire, no injuries.
#
# - MTA has power, but…
# _____________________________________
# NYCT Subway
# New York City
# 7 train service has resumed making all stops after an earlier Con Edison explosion in Queens. Expect extensive delays in 7 train service in both directions. https://t.co/uJhnDFU7su
# _____________________________________
# City of New York
# New York City
# RT @NYPDChiefofDept: The transformer explosion at a #ConEd plant in #Queens is under control and there are no injuries at this time. https:…
# _____________________________________
# NYCT Subway
# New York City
# Service update: There is no [7] and [7D] train service between 74 St-Broadway and Main St in both directions because of a Con Edison loss of power between Main St and Mets-Willets Point.
# _____________________________________
# NYCT Subway
# New York City
# There is no 7 and 7 express train service between 74 St-Broadway and Main St in both directions because of a Con Edison loss of power.
# _____________________________________
# City of New York
# New York City
# RT @FDNY: #FDNY is investigating a transformer incident in Queens at a @ConEdison location. The Department has received numerous calls for…
# _____________________________________
# City of New York
# New York City
# RT @NYCMayor: The NYPD and the FDNY are on scene at a Con Ed facility in Astoria where an apparent transformer explosion just lit up the sk…
# _____________________________________
# NYCT Subway
# New York City
# L train service has resumed.
# https://t.co/siazeNxzx4
# _____________________________________
# NYCT Subway
# New York City
# 1 train service has resumed making station stops at 168 St.
# https://t.co/6mwmsxqYQb
# _____________________________________
# City of New York
# New York City
# RT @NYPD114Pct: Investigating a transformer explosion at Astoria East &amp; North Queens Con Ed power plant. Please avoid 20th Ave &amp; 31 st.
# _____________________________________
# City of New York
# New York City
# RT @NotifyNYC: Expect a heavy presence of emergency personnel in the area of 20th Avenue and 31st Street in Queens. Consider alternate rout…
# _____________________________________
# City of New York
# New York City
# RT @NYPDnews: ADVISORY: The lights you have seen throughout the city appear to have been from a transformer explosion at a Con Ed facility…
# _____________________________________
# NYCT Subway
# New York City
# F train service has resumed with delays.
# https://t.co/PrQ1VusFg4
# _____________________________________
# NYCT Subway
# New York City
# Northbound F trains are running with delays because of an NYPD investigation at Jay St-MetroTech.
# _____________________________________
# NYCT Subway
# New York City
# 1 trains are bypassing 168 St in both directions because of an elevator malfunction at this station.
# _____________________________________
# NYCT Subway
# New York City
# 7 and 7 express trains are holding in stations because of a temporary loss of power between Main St and Mets-Willets Point.
# _____________________________________
# NYCT Subway
# New York City
# Canarsie-bound L trains are running with delays because of signal problems at 1 Av.
# _____________________________________
# City of New York
# New York City
# A travel advisory is in effect for tomorrow. Please take extra care outdoors and use public transit whenever possible. https://t.co/Jw0sxzgmNB https://t.co/dRHUjeDhQS
# _____________________________________
# NYCT Subway
# New York City
# Canarsie-bound L trains are running with delays because a train's brakes were automatically activated at 1 Av.
# _____________________________________
# City of New York
# New York City
# RT @NYCMayorsOffice: A travel advisory is issued for tomorrow (Friday). Expect heavy rain and wind during the morning commute and throughou…
# _____________________________________
# NYCT Subway
# New York City
# R train service has resumed with delays.
# https://t.co/RbldCCMmnC
# _____________________________________
# NYCT Subway
# New York City
# Northbound R trains are running with delays because a train's brakes were activated at 36 St (Bklyn).
# _____________________________________
# NYCT Subway
# New York City
# 7 and 7 express train service has resumed with delays.
# https://t.co/fGNgrgzEk1
# _____________________________________
# NYCT Subway
# New York City
# Service Update: Some 34 St-bound 7 trains will end at Queensboro Plaza or Times Sq-42 St.
#
# Expect delays in 7 and 7 express train service in both directions.
# _____________________________________
# City of New York
# New York City
# ICYMI: NYC Love Your Local initiative selects 20 neighborhood businesses to receive grant awards and expert advice: https://t.co/8ZEa0Wm1xc @NYC_SBS #SmallBusinesses https://t.co/ge70hWlUZ1
# _____________________________________
# NYCT Subway
# New York City
# 7 and 7 express trains are running with delays in both directions because of a train with mechanical problems at 34 St-Hudson Yards.
# _____________________________________
# City of New York
# New York City
# RT @nycemergencymgt: NYC Emergency Management Issues Travel Advisory for Friday
#
# Read more: https://t.co/Yk1537iaJz
# _____________________________________
# NYCT Subway
# New York City
# Some southbound F train service changes because of the ongoing track, signal and power Planned Work in the 53 St tube. See https://t.co/vhZQ2kZ2vb
# _____________________________________
# City of New York
# New York City
# Those needing to get rid of mostly plastic and metal fake Christmas trees should consider selling or donating them. Donation opportunities may be found at https://t.co/QtYWhiS7ie via @NYCSanitation
# _____________________________________
# City of New York
# New York City
# RT @NYCMayor: Veterans like Luke Gasparre gave so much to our city and our country. @NYCVeterans is working every day to make sure we serve…
# _____________________________________
# Flatiron School
# New York, NY
# RT @CourseReport: A #codingbootcamp is opening at @Yale! @FlatironSchool is partnering with @YaleSummer to offer the 10-week course in Summ…
# _____________________________________
# NYCT Subway
# New York City
# B and Q train service has resumed making normal stops.
# https://t.co/1y4zmNsJ1c
# _____________________________________
# City of New York
# New York City
# Looking for ways you can help homeless New Yorkers? @NYCHRA and @NYCDHS are asking for volunteers for the HOPE 2019 survey of New Yorkers sleeping on the streets (Monday, Jan. 28th; 10pm - 4am). Register here: https://t.co/rzDbXbUVMa
# _____________________________________
# NYCT Subway
# New York City
# Q train service has resumed with delays.
# https://t.co/wR79jkV6QN
# _____________________________________
# NYCT Subway
# New York City
# L train service has resumed with delays.
# https://t.co/lL4aPT3tRW
# _____________________________________
# NYCT Subway
# New York City
# Service Update: Southbound B and Q trains are bypassing Neck Rd after someone was fatally struck by a train at this station.
#
# Other service changes remain in effect.
# _____________________________________
# City of New York
# New York City
# .@NYCSanitation will begin its annual curbside collection of Christmas trees on Wednesday, January 2, 2019. Collection runs through Saturday, January 12, weather permitting. https://t.co/lkyiPX1doP
# _____________________________________
# NYCT Subway
# New York City
# L trains are running with delays in both directions because of an NYPD investigation at 8 Av.
# _____________________________________
# NYCT Subway
# New York City
# Northbound B trains are stopping along the D line from Coney Island-Stillwell Av to DeKalb Av.
#
# Northbound Q trains are stopping along the N line from Coney Island-Stillwell Av to DeKalb Av.
#
# Southbound B trains are running local from Prospect Park to Brighton Beach.
# (2/2)
# _____________________________________
# NYCT Subway
# New York City
# Service Update: There are service changes and delays in B and Q train service after someone was fatally struck by a train at Sheepshead Bay.
# (1/2)
# _____________________________________
# NYCT Subway
# New York City
# Service Update: Northbound B trains are stopping along the D line from Coney Island-Stillwell Av to DeKalb Av.
#
# Northbound Q trains are stopping along the N line from Coney Island-Stillwell Av to DeKalb Av.
# _____________________________________
# NYCT Subway
# New York City
# Northbound Q trains are running express from Brighton Beach to Kings Hwy because of an unauthorized person on the tracks at Sheepshead Bay.
# _____________________________________
# City of New York
# New York City
# Despite the federal government shutdown, Medicaid, SNAP benefits and food program, Supplemental Security Income (SSI), HIV/AIDS Services Administration (HASA) Programs, and Cash Assistance are still in effect for New Yorkers. https://t.co/hd7l3y070Y
# _____________________________________
# Flatiron School
# New York, NY
# #3. Coding schools = the future. https://t.co/4CquSAM725
# _____________________________________
# NYCT Subway
# New York City
# Q trains are delayed in both directions because of an NYPD investigation at 96 St.
# _____________________________________
# City of New York
# New York City
# Under New York State Law, it’s illegal to include electronic devices with trash or recycling. @NYCSanitation wants to help New Yorkers ecycleNYC. Find out how you can get an ecycleNYC bin here: https://t.co/roTYigs2tT
# _____________________________________
# NYCT Subway
# New York City
# F train service has resumed with delays.
# https://t.co/7qriPCxx1c
# _____________________________________
# NYCT Subway
# New York City
# L train service has resumed.
# https://t.co/DZE8ekowEo
# _____________________________________
# NYCT Subway
# New York City
# 7 train service has resumed with delays.
# https://t.co/Sw22JYwvov
# _____________________________________
# NYCT Subway
# New York City
# Main St-bound 7 trains are delayed because of an NYPD investigation at Queensboro Plaza.
# _____________________________________
# City of New York
# New York City
# Did you know that the @BKLYNlibrary offers storytime in an array of languages? Check out the full listing here: https://t.co/65uoAj3qsu
# _____________________________________
# MTA
# New York Metro Region
# Congratulations to proud parents Maria and Ivan and newborn Alie! She was born in the wee hours of Dec. 26 at the Queens Midtown Tunnel with a little help from MTA Bridges and Tunnels officers. Lieut. Harry Persad, a former EMT before joining the MTA, helped with the delivery. https://t.co/WGqrdYT8pu
# _____________________________________
# NYCT Subway
# New York City
# L trains are running with delays in both directions between Broadway Junction and Canarsie-Rockaway Pkwy because of track maintenance in that area.
# _____________________________________
# Flatiron School
# New York, NY
# RT @aviflombaum: This December 60 @FlatironSchool grads got new jobs. 60. During what's suppose to be a slow month for hiring. And we've st…
# _____________________________________
# Flatiron School
# New York, NY
# RT @aviflombaum: Love how pretty code is - from https://t.co/sAxrsWjfAs https://t.co/ybdOYgtp9w
# _____________________________________
# City of New York
# New York City
# Add volunteering with older New Yorkers to your New Year's Resolution. @NYCSeniors' Friendly Visiting program matches volunteers with older adults to form friendships and intergenerational understanding. Learn how to become a volunteer: https://t.co/BrLEiQt0nB
# _____________________________________
# City of New York
# New York City
# The 2-min #OneNYC survey could make a difference in our city! Share your ideas and opinions here: https://t.co/vtdrLO6bJN
# _____________________________________
# NYCT Subway
# New York City
# Southbound E trains have resumed making express stops from Jamaica-Van Wyck to Forest Hills-71 Av after someone needed medical assistance at Kew Gardens-Union Tpke.
#
# https://t.co/skOOuBU9E5
# _____________________________________
# NYCT Subway
# New York City
# Canarsie-bound L train service has resumed after we removed a train with door problems at 1 Av.
# https://t.co/GT7Xe7MGhf
# _____________________________________
# NYCT Subway
# New York City
# Southbound E trains are running local from Jamaica-Van Wyck to 71 Av because someone needs medical assistance at Union Tpke.
# _____________________________________
# City of New York
# New York City
# Make getting an @IDNYC card one of your New Year's Resolutions! #IDNYC provides exclusive discounts &amp; deals on entertainment, prescription drugs, transportation, education, fitness and more. Apply here: https://t.co/tHkzAVQPBs
# _____________________________________
# NYCT Subway
# New York City
# Canarsie-bound L trains are running with delays while we remove a train with door problems from service at 1 Av.
# _____________________________________
# NYCT Subway
# New York City
# Southbound F trains are running with delays because of signal problems at Avenue I.
# _____________________________________
# NYCT Subway
# New York City
# J and Z Customers: from 9:30 PM 12/28, until 5AM 1/7, J trains will not run between Jamaica Center and 121 St while we rebuild a section of track in Queens. Details: https://t.co/PABjqAJwbH https://t.co/BUX5FnClN8
# _____________________________________
# City of New York
# New York City
# RT @NYCMayorsOffice: Today will be mostly sunny with a high of 42! It looks like rain all day Friday so enjoy an outdoor break today if you…
# _____________________________________
# NYCT Subway
# New York City
# A and C trains have resumed making all regular stops after we corrected a switch problem at Utica Av.
# https://t.co/uyjKeelRJs
# _____________________________________
# NYCT Subway
# New York City
# Additional Update: LIRR is accommodating MetroCard holders at the following station: EN, Nostrand Av and Atlantic Av.
# _____________________________________
# NYCT Subway
# New York City
# Update: There is limited A and C train service between Euclid Av and Jay St-MetroTech in both directions.
# See a station agent for a courtesy pass for continuing train or bus service.
# _____________________________________
# NYCT Subway
# New York City
# Northbound A and C trains are running with delays because of a switch problem at Utica Av.
# _____________________________________
# City of New York
# New York City
# Learn to swim with @NYCParks classes starting January 7! Adult lessons will be offered on Saturdays. Register today: https://t.co/1qoLS3bEXo
# _____________________________________
# NYCT Subway
# New York City
# Broad St bound J trains have resumed with delays after we removed a train with mechanical problems from service at Alabama Av.
# https://t.co/gJQbtTSiu7
# _____________________________________
# NYCT Subway
# New York City
# Southbound A trains have resumed with delays after we removed a train with mechanical problems from service at Euclid Av.
# https://t.co/VZm1fs4VnK
# _____________________________________
# NYCT Subway
# New York City
# Broad St bound J trains are delayed while we remove a train with mechanical problems from service at Alabama Av.
# _____________________________________
# NYCT Subway
# New York City
# Southbound A trains are running with delays while we remove a train with mechanical problems from service at Euclid Av.
# _____________________________________
# City of New York
# New York City
# ICYMI: @NYCMayor supports the safe and fair legalization of marijuana in New York City. https://t.co/JNldoCEwi8
# _____________________________________
# NYCT Subway
# New York City
# Southbound 4 trains have resumed with delays after we assisted someone who required medical assistance at 183 St.
# https://t.co/krLWDeVhHa
# _____________________________________
# NYCT Subway
# New York City
# Southbound 4 trains are delayed because someone requires medical assistance at 183 St.
# _____________________________________
# NYCT Subway
# New York City
# L train service has resumed with delays after our crews repaired a signal malfunction between Bedford Av and 1 Av.
# https://t.co/zMv7ChoqAr
# _____________________________________
# NYCT Subway
# New York City
# L trains are delayed in both directions because of a signal malfunction between Bedford Av and 1 Av.
# _____________________________________
# NYCT Subway
# New York City
# Flushing-Main St bound 7 trains are running with delays after we removed a train with mechanical problems from service at 34 St-Hudson Yards.
# _____________________________________
# NYCT Subway
# New York City
# Northbound 4 and 5 train service has resumed with delays after we moved a stalled train from Atlantic Av Barclays Ctr.
# https://t.co/UaIZ7Qqsem
# _____________________________________
# NYCT Subway
# New York City
# Northbound 4 and 5 trains are running local from Franklin Av to Atlantic Av-Barclays Ctr because of a stalled train at Atlantic Av-Barclays Ctr.
# _____________________________________
# NYCT Subway
# New York City
# L train service has resumed with delays after earlier signal and switch problems.
# https://t.co/0Jlu7SUixR
# _____________________________________
# NYCT Subway
# New York City
# Update: There is no L train service between 8 Av and Bedford Av in both directions.
# For service in Manhattan, take M14 bus service
# For service between Manhattan and Brooklyn, consider taking A, C, J, and M train service.
# https://t.co/HCTgFa1JAf
# _____________________________________
# NYCT Subway
# New York City
# There are service changes and delays in L train service while our crews repair a signal problem in the tunnel between Bedford Av and 1 Av.
# Canarsie-bound L trains are stopping at the 8 Av-bound platforms 3 Av, 1 Av and Bedford Av.
# _____________________________________
# NYCT Subway
# New York City
# Canarsie Rockaway Parkway bound L trains have resumed with delays after we moved a stalled work train from Montrose Ave.
# https://t.co/RcC77Y25TZ
# _____________________________________
# NYCT Subway
# New York City
# Coney Island-bound F trains are proceeding with delays Fort Hamilton Parkway after our crews removed a train from service for an unsanitary condition.
# _____________________________________
# NYCT Subway
# New York City
# Canarsie Rockaway Pkwy bound L trains are delayed because of a stalled work train at Montrose Av.
# _____________________________________
# NYCT Subway
# New York City
# Jamaica-179 St-bound F trains are running with delays after earlier police activity at W 4th St-Washington Sq.
# _____________________________________
# NYCT Subway
# New York City
# R trains are no longer running with delays after an earlier NYPD activity at Bay Ridge-95 St. https://t.co/F01ITFfLrF
# _____________________________________
# NYCT Subway
# New York City
# R trains are running with delays in both directions because of NYPD activity at Bay Ridge-95 St.
# _____________________________________
# NYCT Subway
# New York City
# For service to bypassed stations, consider transferring to a northbound 1 or 2 train at 14 St or Chambers St, using nearby A train stations, or using the nearby M20 bus service on 7th Av.
#
# Expect delays in 1 and 2 trains in both directions. (2/2)
# _____________________________________
# NYCT Subway
# New York City
# Southbound 1 and 2 trains are making express stops from 34 St-Penn Station to Chambers St because someone was fatally struck by a train at 23 St. Emergency teams are on scene. (1/2)
# _____________________________________
# NYCT Subway
# New York City
# Southbound 1 and 2 trains are making express stops from 34 St-Penn Station to Chambers St because someone was fatally struck by a train at 23 St.
#
# For service to bypassed stations, use nearby A train stations or transfer to northbound 1 or 2 trains at 14 St or Chambers St.
# _____________________________________
# NYCT Subway
# New York City
# Service update: Southbound 1 and 2 trains are running express from 34 St-Penn Station to Chambers St because someone was fatally struck by a train at 23 St.
#
# For service to bypassed stations, consider using a northbound train.
#
# Expect delays in 1 and 2 train in both directions.
# _____________________________________
# NYCT Subway
# New York City
# Euclid-bound C trains are moving with delays after we removed a train from service at Kingston-Throop Aves. https://t.co/LtzLS54CP2
# _____________________________________
# NYCT Subway
# New York City
# 1, 2, and 3 trains are holding in stations in both directions because a customer was struck by a train at 23 St. Emergency crews are en route to assist.
# _____________________________________
# NYCT Subway
# New York City
# Euclid-bound C trains are delayed while we remove a train from service at Kingston-Throop Aves.
# _____________________________________
# NYCT Subway
# New York City
# We’re back! The 174-175 Sts B/D station has reopened with:
# ✅Repaired platform structural steel and concrete
# ✅Replaced platform edges and repaired stairways
# ✅Added new digital wayfinding and customer information screens https://t.co/HAbB7hsePv
# _____________________________________
# NYCT Subway
# New York City
# Northbound F and G trains are now proceeding with delays at Bergen St after our crews successfully moved a stalled train. https://t.co/S6qsdBIm3R
# _____________________________________
# NYCT Subway
# New York City
# Northbound F and G trains are now proceeding with delays at Bergen St after our crews successfully moved a stalled train.
# _____________________________________
# City of New York
# New York City
# ICYMI: @NYCPlanning Director Marisa Lago marked the City Council’s approval of a new City Planning Commission Special Permit that would be required in order to start new hotels and motels in light manufacturing districts. https://t.co/EuQc34liMi
# _____________________________________
# NYCT Subway
# New York City
# Northbound F and G trains are delayed because of a stalled train at Bergen St.
# _____________________________________
# NYCT Subway
# New York City
# Regular E train service has resumed between West 4 St and World Trade Center after EMS helped someone requiring medical assistance at World Trade Center. https://t.co/OTrjNw6dRf
# _____________________________________
# NYCT Subway
# New York City
# Service Update: Some southbound E trains are stopping along the F line from West 4 St and ending at 2 Av because someone needs medical assistance at World Trade Ctr. https://t.co/LKqWfG9yVe
# _____________________________________
# City of New York
# New York City
# Learn about the fascinating history of famous film and television shooting locations in New York City with these free podcasts narrated by actors @JuliannaMargs and @MatthewModine. https://t.co/OSIej9z4s1 via @MadeinNY
# _____________________________________
# NYCT Subway
# New York City
# E trains are delayed in both directions because someone requires medical assistance at World Trade Center.
# _____________________________________
# Flatiron School
# New York, NY
# RT @BekahHW: 1. Ran a 5k the day after the 2yr anniversary of 2 of my organs rupturing.
# 2. Got a scholarship to @FlatironSchool.
# 3. Start…
# _____________________________________
# Flatiron School
# New York, NY
# RT @jasmineLAD16: Merry Christmas y’all! 🎄 keeping it going @CodeNewbies @CodePen @FlatironSchool #100daysofcode https://t.co/WrgDr4uDOn
# _____________________________________
# City of New York
# New York City
# .@NYCHealthSystem announced that it has distributed more than 13,000 opioid reversal kits to people visiting New York City’s jails since the launch of HealingNYC. https://t.co/DswLqOOPNN
# _____________________________________
# City of New York
# New York City
# While school is out, your kids can experience nature in a hands-on and fun way at @NYCParks throughout the city for Kids Week! Find all the events here: https://t.co/7dwnBXtlIs
# _____________________________________
# City of New York
# New York City
# RT @NYCMayorsOffice: In honor of William Thompson Sr., former New York State Senator, New York City Council Member and associate justice of…
# _____________________________________
# City of New York
# New York City
# Did you know @CitiBikeNYC is only $5 a month if you live in @NYCHA or receive SNAP? Find details here: https://t.co/BoeRC3zoxz
# _____________________________________
# City of New York
# New York City
# Thanks to a partnership between @NYCHA and Zipcar, nearly 25 Zipcars can be found at 10 #NYCHA developments in #Brooklyn and the #Bronx. NYCHA residents can join for free to reserve wheels when you want them. https://t.co/qcMvSi5Uar
# _____________________________________
# City of New York
# New York City
# RT @NYC_DOT: NYC’s winter weather ❄️🌞 🌧️🍃 is hard to predict, and hard on #NYCstreets. Here are four easy ways to report a pothole:
#
# P.S. y…
# _____________________________________
# NYCT Subway
# New York City
# 2 train service has resumed making local stops.
# https://t.co/cQO7I9txxw
# _____________________________________
# City of New York
# New York City
# RT @greenyc: For every degree you lower your thermostat, you can save up to five percent of your heating bill, and you improve air quality,…
# _____________________________________
# City of New York
# New York City
# RT @NYCParks: The end of Christmas marks the start of NYC's unique holiday tradition: #Mulchfest! Bring your family to a park near you to s…
# _____________________________________
# NYCT Subway
# New York City
# Southbound 2 trains are running express from Gun Hill Rd to E 180 St because someone requires medical assistance at Gun Hill Rd.
# _____________________________________
# NYCT Subway
# New York City
# 4, 5 and 6 train service has resumed with delays after someone required medical assistance at 14 St-Union Sq.
# _____________________________________
# City of New York
# New York City
# .@NYCHousing is launching the Neighborhood Pillars fund to help non-profits &amp; community organizations buy apartment buildings, preserve affordability &amp; keep New Yorkers in their homes. https://t.co/3g23UrhC4R
# _____________________________________
# City of New York
# New York City
# RT @NYCDHS: For those living on the streets, being seen is the first step to being helped. That’s where you come in. Do your part on and jo…
# _____________________________________
# Flatiron School
# New York, NY
# RT @WeWork: Sometimes you just need to reset. #wellnesswednesday https://t.co/ytGyuXGVJH
# _____________________________________
# City of New York
# New York City
# .@NYCSanitation announced that there will be NO trash collection (including organics and recycling) on New Year’s Day (Tuesday’ January 1st). More information: https://t.co/Hc365suwiB
# _____________________________________
# NYCT Subway
# New York City
# D train service has resumed.
# https://t.co/QWPOQPUEmV
# _____________________________________
# City of New York
# New York City
# .@NYCHousing is seeking developers to develop affordable homes for seniors in the Bronx. https://t.co/RfLfugtEg3
# _____________________________________
# NYCT Subway
# New York City
# F train service has resumed with delays.
# https://t.co/u1wFw9nuGR
# _____________________________________
# NYCT Subway
# New York City
# Northbound R and W train service has resumed with delays following earlier track maintenance at 23 St.
# _____________________________________
# NYCT Subway
# New York City
# Northbound F trains are running with delays because a train's brakes were automatically activated at Avenue I.
# _____________________________________
# City of New York
# New York City
# .@ACSNYC and @FDNY are partnering together to prevent future fires in NYC.  https://t.co/OUVJt8SvCt
# _____________________________________
# NYCT Subway
# New York City
# 2 and 5 train service has resumed after we moved a train with mechanical problems at Flatbush Av-Brooklyn College.
# https://t.co/vcxaQMPJjC
# _____________________________________
# NYCT Subway
# New York City
# Some southbound D trains end at Bay Parkway because of track maintenance at Coney Island-Stillwell Av.
#
# Expect delays in both directions.
# _____________________________________
# NYCT Subway
# New York City
# Northbound R and W trains are running with delays because of track maintenance at 23 St.
# _____________________________________
# NYCT Subway
# New York City
# 2 and 5 trains are running with delays in both directions while we remove a train with mechanical problems from service at Flatbush Av.
# _____________________________________
# City of New York
# New York City
# RT @NYCCHR: As we approach a new year, there's lots going on at the Commission!  Keep up with Human Rights in NYC by subscribing to our e-n…
# _____________________________________
# NYCT Subway
# New York City
# 2 and 3 train service is resuming after we removed an unauthorized person from the tracks at 135 St.
# https://t.co/qrkraqMfbq
# _____________________________________
# NYCT Subway
# New York City
# 2 and 3 trains are running with delays in both directions while NYPD attempts to remove an unauthorized person on the tracks at 135 St.
# _____________________________________
# City of New York
# New York City
# ICYMI: Through new partnership, frontline @ACSNYC child welfare workers will get hands-on-training from @FDNY on how to educate children &amp; families of fire hazards: https://t.co/kVTggssm66 https://t.co/Ymamc73ZYl
# _____________________________________
# City of New York
# New York City
# RT @NYCParks: Skate with us in @Prospect_Park at @LakesideBKLYN, Brooklyn's only outdoor ice rink. https://t.co/JjIez53CCy
# _____________________________________
# Flatiron School
# New York, NY
# RT @aviflombaum: Thanks @WeWork for being amazing to our students and community. https://t.co/NpH16frfPH
# _____________________________________
# NYCT Subway
# New York City
# J trains have resumed making all regular stops after we corrected a signal problem at Chauncey St.
# https://t.co/ET1YCluoIH
# _____________________________________
# NYCT Subway
# New York City
# Update: There is no J train service between Broadway Junction and Marcy Av in both directions.
# _____________________________________

# %% [markdown]
# Thats is great. We are getting some meaningful information indeed.
#
# #### Before we proceed ....
# *We are using a test account and following a number of AI, Data science and Tech groups/companies to progress through the lab. Based on your own preferences , your results may be different than what you see here. You are encouraged to ask some meaningful questions and parse the JSON around how YOU use twitter.**

# %% [markdown]
# ###  Store the Tweets JSON File

# %% [markdown]
# It is always a good idea to store the tweets as a JSON file as executing above cells will bring in new tweets and will keep re-writing the object. This can have negative impacts on your analysis (unless you are analyzing live streams).
# * Store the `my_timeline_tweets` JSON object in `tweets.json` file.

# %%
# Store my_timeline_tweets as a JSON file
import json
new_list = []
for i in my_timeline_tweets:
    new_list.append(i._json)

with open('tweets.json', 'w') as file:
    file.write(json.dumps(new_list, indent=4))

# %% [markdown]
# #### Open `tweets.json` and inspect its contents in relation to the JSON object shown below.

# %% [markdown]
# ## NATURAL LANGUAGE PROCESSING
#
# Twitter data is of the most favorite dataset for data scientists and Natural Language Processing (NLP) researchers. Besides its magnanimous size, Twitter data has other unique qualities as well: it comprises of real-life conversations, limited word length, rich variety, and real-time data stream. Advanced analytics on Twitter data needs one to go beyond the words and parse sentences into syntactic representations to develop a better contextual understanding of the tweet content. We shall cover more of that in our sections dedicated to NLP.
#
# ![](https://static1.squarespace.com/static/5552e2d6e4b098f713cf2613/t/56e3930327d4bdfdac7c34a9/1457754894624/?format=750w)
#
# Here we shall look at some basic techniques that you might want to use for cleaning text data and look for important words, mentions, URLs  or hashtags etc.
#
# #### Good old word count ..
#
# A very fundamental NLP skill, without using any complicated algorithms is to count the occurrences of words/terms (known as **TERM FREQUENCIES** of TFs). With this, we can observe what are the terms most commonly used in the data set.
#
# ### Tokenization
#
# Tokenization is an NLP specific term which concerns with breaking down a text document (like a tweet) into its tokens (words/terms). Below we have a simple custom tokenization routine that will parse each tweet and split it into words/terms to capture Twitter-specific aspects of the text, such as **#hashtags**, **@mentions**, **emoticons** and **URLs**. In order to tokenize , you simply need to pass each tweet to the `preprocess_tweet()` function below and it will be split into its constituent terms.

# %%
# A SIMPLE TOKENZIER IMPLEMENTAION 

# Import Regular Expressions
import re

# Identify some basic emoticon elements (face, nose, mouth )- you are encouraged to add more for other emoticons
emoticons_str = r"""
    (?:
        [:=;] # Eyes
        [oO\-]? # Nose (optional)
        [D\)\]\(\]/\\OpP] # Mouth
    )"""

# Identify Twitter specific elements in a tweet
regex_str = [
    emoticons_str,
    r'<[^>]+>', # HTML tags
    r'(?:@[\w_]+)', # @-mentions
    r"(?:\#+[\w_]+[\w\'_\-]*[\w_]+)", # hash-tags
    r'http[s]?://(?:[a-z]|[0-9]|[$-_@.&amp;+]|[!*\(\),]|(?:%[0-9a-f][0-9a-f]))+', # URLs
 
    r'(?:(?:\d+,?)+(?:\.?\d+)?)', # numbers
    r"(?:[a-z][a-z'\-_]+[a-z])", # words with - and '
    r'(?:[\w_]+)', # other words
    r'(?:\S)' # anything else
]
    
tokens_re = re.compile(r'('+'|'.join(regex_str)+')', re.VERBOSE | re.IGNORECASE)
emoticon_re = re.compile(r'^'+emoticons_str+'$', re.VERBOSE | re.IGNORECASE)
 
def tokenize(s):
    return tokens_re.findall(s)
 
def preprocess_tweet(s, lowercase=False):
    tokens = tokenize(s)
    if lowercase:
        tokens = [token if emoticon_re.search(token) else token.lower() for token in tokens]
    return tokens

# %% [markdown]
# The code above uses a lot of regular expressions to search for twitter specific terms. Let's pass in a sample tweet to `preprocess_tweet` function and inspect the output.

# %%
example_tweet = 'ExampleTweet @datascienceguy: You are an NLP superstar :D http://example.com #NLP #datascience :P'
print(preprocess_tweet(example_tweet))
# Out:
# ['ExampleTweet', '@datascienceguy', ':', 'You', 'are', 'an', 'NLP', 'superstar', ':D', 'http://example.com', '#NLP', '#datascience', ':P']

# %% [markdown]
# So here you can see that each word, URL, emoticon has been sucessfully identified as a **Term**. Now we can do some basic analysis with these terms.

# %% [markdown]
# ### Count Term Frequencies
#
# As a first step, we can simply count the total number of occurances of teach term. Keep in mind that at this stage , we are also counting punctuation marks and common words like "the" "of" "for etc.
#
# Perform following tasks.
# * Load the JSON file `tweets.json` into a new variable called `data`.
# * In order to keep track of the frequencies while we are processing the tweets, we can use `collections.Counter()`  from the `Counter` library, which behaves is a dictionary (term: count) with some useful methods like `update()` and `most_common()`. [Here is a link to official doc. for consultation](https://docs.python.org/2/library/collections.html).
# * Iterate through the list of tweets update the term counter using `.update()` method for all terms after each iteration.
# * Count all the terms and list top ten most common terms

# %%
# Count all terms frequency from the saved JSON file


with open('tweets.json', encoding='utf-8') as json_file:  
    data = json.load(json_file)

cnt = Counter()
for tweet in data:
    i = preprocess_tweet(tweet['full_text'])
    for z in list(range(0, len(i))):
        cnt[i[z]] += 1
cnt.most_common()

# [(':', 142), ('.', 94), (',', 92), ('RT', 91), ('the', 81), ('to', 65), 
# ('…', 65), ('of', 65), ('and', 64), ('a', 58)]
# Out:
# [('.', 233),
#  ('and', 124),
#  ('at', 113),
#  ('trains', 104),
#  ('a', 95),
#  ('are', 93),
#  ('train', 82),
#  (':', 79),
#  ('to', 77),
#  (',', 76),
#  ('St', 75),
#  ('in', 74),
#  ('service', 74),
#  ('with', 74),
#  ('Av', 66),
#  ('of', 64),
#  ('the', 60),
#  ('delays', 56),
#  ('from', 50),
#  ('because', 50),
#  ('after', 42),
#  ('resumed', 38),
#  ('we', 35),
#  ('RT', 34),
#  ('running', 33),
#  ('2', 32),
#  ('has', 30),
#  ('…', 27),
#  ('Northbound', 27),
#  ('1', 26),
#  ('Southbound', 26),
#  ('both', 25),
#  ('directions', 25),
#  ('is', 24),
#  ('7', 24),
#  ('on', 23),
#  ('between', 22),
#  ('New', 21),
#  ('L', 21),
#  ('an', 21),
#  ('-', 20),
#  ('for', 20),
#  ('delayed', 20),
#  ('3', 19),
#  ('4', 18),
#  ('problems', 18),
#  ('F', 17),
#  ('stops', 16),
#  ('signal', 16),
#  ('while', 15),
#  ('have', 15),
#  ('express', 15),
#  ('or', 15),
#  ('will', 14),
#  ('making', 14),
#  ('earlier', 14),
#  ('NYPD', 14),
#  ('Q', 14),
#  ('our', 14),
#  ('(', 14),
#  (')', 14),
#  ('you', 14),
#  ('someone', 14),
#  ('Queens', 13),
#  ('be', 13),
#  ('For', 13),
#  ('track', 12),
#  ('no', 12),
#  ('A', 12),
#  ('was', 12),
#  ('Coney', 12),
#  ('/', 11),
#  ('5', 11),
#  ('your', 11),
#  ('problem', 11),
#  ('E', 11),
#  ('mechanical', 11),
#  ('D', 11),
#  ('!', 11),
#  ('J', 10),
#  ('moved', 10),
#  ('’', 10),
#  ('34', 10),
#  ('Update', 10),
#  ('There', 10),
#  ('activity', 9),
#  ('Expect', 9),
#  ('The', 9),
#  ('removed', 9),
#  ('brakes', 9),
#  ('activated', 9),
#  (';', 9),
#  ('consider', 9),
#  ('23', 9),
#  ('Service', 9),
#  ('stations', 9),
#  ('maintenance', 9),
#  ('Con', 9),
#  ('explosion', 9),
#  ('Island-Stillwell', 9),
#  ('by', 9),
#  ('medical', 9),
#  ('assistance', 9),
#  ('Some', 8),
#  ('all', 8),
#  ('s', 8),
#  ('line', 8),
#  ('that', 8),
#  ('here', 8),
#  ('N', 8),
#  ('remove', 8),
#  ('stopping', 8),
#  ('Bedford', 8),
#  ('stalled', 8),
#  ('&', 8),
#  ('amp', 8),
#  ('crews', 8),
#  ('R', 8),
#  ('local', 7),
#  ('York', 7),
#  ('southbound', 7),
#  ('work', 7),
#  ('Yorkers', 7),
#  ("train's", 7),
#  ('were', 7),
#  ('C', 7),
#  ('proceeding', 7),
#  ('Main', 7),
#  ('nearby', 7),
#  ('power', 7),
#  ('B', 7),
#  ('rain', 6),
#  ('January', 6),
#  ('@NYCSanitation', 6),
#  ('149', 6),
#  ('8', 6),
#  ('Canarsie-bound', 6),
#  ('temporary', 6),
#  ('th', 6),
#  ('transformer', 6),
#  ('bus', 6),
#  ('station', 6),
#  ('can', 6),
#  ('struck', 6),
#  ('new', 6),
#  ('City', 6),
#  ('Center', 5),
#  ('this', 5),
#  ('northbound', 5),
#  ('1,', 5),
#  ('end', 5),
#  ('Christmas', 5),
#  ('city', 5),
#  ('malfunction', 5),
#  ('Avenue', 5),
#  ('now', 5),
#  ('bypassed', 5),
#  ('6', 5),
#  ('Central', 5),
#  ('Edison', 5),
#  ('fire', 5),
#  ('74', 5),
#  ('St-Broadway', 5),
#  ('using', 5),
#  ('NYC', 5),
#  ('fatally', 5),
#  ('along', 5),
#  ('Bay', 5),
#  ('bound', 5),
#  ('Chambers', 5),
#  ('corrected', 4),
#  ('via', 4),
#  ('Plaza', 4),
#  ('G', 4),
#  ('Bergen', 4),
#  ('Manhattan', 4),
#  ('@NYCMayorsOffice', 4),
#  ('day', 4),
#  ('out', 4),
#  ('?', 4),
#  ('Find', 4),
#  ('St-Grand', 4),
#  ('Concourse', 4),
#  ('longer', 4),
#  ('overnight', 4),
#  ('facility', 4),
#  ('Av-bound', 4),
#  ('42', 4),
#  ('2,', 4),
#  ('Park', 4),
#  ('North', 4),
#  ('electrical', 4),
#  ('20', 4),
#  ('Astoria', 4),
#  ('door', 4),
#  ('—', 4),
#  ('Ed', 4),
#  ('MTA', 4),
#  ('St-Hudson', 4),
#  ('Yards', 4),
#  ('@NYCMayor', 4),
#  ('st', 4),
#  ('investigation', 4),
#  ('ICYMI', 4),
#  ('changes', 4),
#  ('@FlatironSchool', 4),
#  ('help', 4),
#  ('DeKalb', 4),
#  ('how', 4),
#  ('Atlantic', 4),
#  ('@NYCParks', 4),
#  ('Ctr', 4),
#  ('World', 4),
#  ('Trade', 4),
#  ('not', 3),
#  ('Jamaica', 3),
#  ('2019', 3),
#  ("Year's", 3),
#  ('today', 3),
#  ('heavy', 3),
#  ('regular', 3),
#  ('Lots', 3),
#  ('96', 3),
#  ('College', 3),
#  ('survey', 3),
#  ('make', 3),
#  ('trees', 3),
#  ('community', 3),
#  ('so', 3),
#  ('throughout', 3),
#  ('Brooklyn', 3),
#  ('its', 3),
#  ('storage', 3),
#  ('automatically', 3),
#  ('platforms', 3),
#  ('take', 3),
#  ('110', 3),
#  ('update', 3),
#  ('Please', 3),
#  ('area', 3),
#  ('@ConEdison', 3),
#  ('substation', 3),
#  ('caused', 3),
#  ('en', 3),
#  ('No', 3),
#  ('injuries', 3),
#  ('Island-bound', 3),
#  ('36', 3),
#  ('Ave', 3),
#  ('180', 3),
#  ('there', 3),
#  ('know', 3),
#  ('loss', 3),
#  ('@FDNY', 3),
#  ('up', 3),
#  ('effect', 3),
#  ('Friday', 3),
#  ('St-bound', 3),
#  ('Sq', 3),
#  ('Emergency', 3),
#  ('more', 3),
#  ('get', 3),
#  ('10', 3),
#  ('Rd', 3),
#  ('unauthorized', 3),
#  ('person', 3),
#  ('tracks', 3),
#  ('it', 3),
#  ('helped', 3),
#  ('@aviflombaum', 3),
#  ('Learn', 3),
#  ('switch', 3),
#  ('Euclid', 3),
#  ('required', 3),
#  ('requires', 3),
#  ('Parkway', 3),
#  ('W', 3),
#  ('14', 3),
#  ('St-Penn', 3),
#  ('Station', 3),
#  ('✅', 3),
#  ('being', 3),
#  ('Z', 2),
#  ('Customers', 2),
#  ('9', 2),
#  ('30', 2),
#  ('PM', 2),
#  ('12', 2),
#  ('28,', 2),
#  ('until', 2),
#  ('AM', 2),
#  ('7,', 2),
#  ('run', 2),
#  ('121', 2),
#  ('rebuild', 2),
#  ('section', 2),
#  ('Details', 2),
#  ('https://t.co/PABjqAJwbH', 2),
#  ('Make', 2),
#  ('year', 2),
#  ('Here', 2),
#  ('code', 2),
#  ('should', 2),
#  ('continue', 2),
#  ('through', 2),
#  ('much', 2),
#  ('https://t.co/SrIf9RnUgM', 2),
#  ('137', 2),
#  ('St-City', 2),
#  ('103', 2),
#  ('min', 2),
#  ('#OneNYC', 2),
#  ('https://t.co/vtdrLO6bJN', 2),
#  ('Crown', 2),
#  ('Hts-Utica', 2),
#  ('Junius', 2),
#  ('repair', 2),
#  ('Wednesday', 2),
#  ('Saturday', 2),
#  ('12,', 2),
#  ('recycled', 2),
#  ('https://t.co/lkyiPX1doP', 2),
#  ('but', 2),
#  ('their', 2),
#  ('high', 2),
#  ('electronic', 2),
#  ('devices', 2),
#  ('need', 2),
#  ('curbside', 2),
#  ('form', 2),
#  ('moving', 2),
#  ('Bowling', 2),
#  ('Green', 2),
#  ('57', 2),
#  ('Burnside', 2),
#  ('had', 2),
#  ('167', 2),
#  ('near', 2),
#  ('As', 2),
#  ('taking', 2),
#  ('M', 2),
#  ('Canal', 2),
#  ('St-Herald', 2),
#  ('Square', 2),
#  ('Fulton', 2),
#  ('Grand', 2),
#  ('@NYPD114Pct', 2),
#  ('avoid', 2),
#  ('brief', 2),
#  ('Street', 2),
#  ('which', 2),
#  ('125', 2),
#  ('@nycgob', 2),
#  ('est', 2),
#  ('á', 2),
#  ('luz', 2),
#  ('La', 2),
#  ('se', 2),
#  ('que', 2),
#  ('@NYPDnews', 2),
#  ('incident', 2),
#  ('St-Flushing', 2),
#  ('Simpson', 2),
#  ('extensive', 2),
#  ('some', 2),
#  ('transfer', 2),
#  ('@LGAairport', 2),
#  ('investigating', 2),
#  ('plant', 2),
#  ('[', 2),
#  (']', 2),
#  ('Mets-Willets', 2),
#  ('Point', 2),
#  ('scene', 2),
#  ('where', 2),
#  ('just', 2),
#  ('168', 2),
#  ('31', 2),
#  ('seen', 2),
#  ('Jay', 2),
#  ('St-MetroTech', 2),
#  ('bypassing', 2),
#  ('holding', 2),
#  ('travel', 2),
#  ('advisory', 2),
#  ('tomorrow', 2),
#  ('use', 2),
#  ('Queensboro', 2),
#  ('Love', 2),
#  ('receive', 2),
#  ('See', 2),
#  ('mostly', 2),
#  ('them', 2),
#  ('found', 2),
#  ('like', 2),
#  ('every', 2),
#  ('partnering', 2),
#  ('ways', 2),
#  ('@NYCDHS', 2),
#  ('volunteers', 2),
#  ('streets', 2),
#  ('Register', 2),
#  ('collection', 2),
#  ('weather', 2),
#  ('Brighton', 2),
#  ('Beach', 2),
#  ('Sheepshead', 2),
#  ('SNAP', 2),
#  ('program', 2),
#  ('future', 2),
#  ('State', 2),
#  ('trash', 2),
#  ('recycling', 2),
#  ('ecycleNYC', 2),
#  ('Did', 2),
#  ('former', 2),
#  ('Broadway', 2),
#  ('Junction', 2),
#  ('Pkwy', 2),
#  ('60', 2),
#  ('month', 2),
#  ('older', 2),
#  ('Jamaica-Van', 2),
#  ('Wyck', 2),
#  ('71', 2),
#  ('Tpke', 2),
#  ('needs', 2),
#  ('I', 2),
#  ('outdoor', 2),
#  ('if', 2),
#  ('Utica', 2),
#  ('following', 2),
#  ('Broad', 2),
#  ('Alabama', 2),
#  ('183', 2),
#  ('repaired', 2),
#  ('Av-Barclays', 2),
#  ('Canarsie', 2),
#  ('Rockaway', 2),
#  ('Montrose', 2),
#  ('Ridge', 2),
#  ('95', 2),
#  ('Euclid-bound', 2),
#  ('Kingston-Throop', 2),
#  ('Aves', 2),
#  ('customer', 2),
#  ('platform', 2),
#  ('information', 2),
#  ('successfully', 2),
#  ('Council', 2),
#  ('Commission', 2),
#  ('start', 2),
#  ('West', 2),
#  ('free', 2),
#  ('y', 2),
#  ('going', 2),
#  ('announced', 2),
#  ('only', 2),
#  ('@NYCHA', 2),
#  ('Thanks', 2),
#  ('partnership', 2),
#  ('️', 2),
#  ('hard', 2),
#  ('Gun', 2),
#  ('Hill', 2),
#  ('@NYCHousing', 2),
#  ('homes', 2),
#  ('@WeWork', 2),
#  ('@ACSNYC', 2),
#  ('Flatbush', 2),
#  ('135', 2),
#  ('https://t.co/Q63O1kWNVR', 1),
#  ('best', 1),
#  ('yet', 1),
#  ('19', 1),
#  ('reasons', 1),
#  ('why', 1),
#  ('learning', 1),
#  ('resolutions', 1),
#  ('list', 1),
#  ('https://t.co/vTHbZ558Ux', 1),
#  ('https://t.co/1ZMwugpqjE', 1),
#  ('@NWSNewYorkNY', 1),
#  ('Widespread', 1),
#  ('occasional', 1),
#  ('possib', 1),
#  ('residual', 1),
#  ('as', 1),
#  ('normalizes', 1),
#  ('https://t.co/3dLsonZYwI', 1),
#  ('most', 1),
#  ('important', 1),
#  ('issue', 1),
#  ('facing', 1),
#  ('___________', 1),
#  ('Take', 1),
#  ('voice', 1),
#  ('heard', 1),
#  ('@NYClimate', 1),
#  ('https://t.co/QbwD00bZ5j', 1),
#  ('Clean', 1),
#  ('non-bagged', 1),
#  ('left', 1),
#  ('curb', 1),
#  ('chipped', 1),
#  ('mixed', 1),
#  ('leaves', 1),
#  ('into', 1),
#  ('compost', 1),
#  ('parks', 1),
#  ('institutions', 1),
#  ('gardens', 1),
#  ('Jackson', 1),
#  ('Hts-Roosevelt', 1),
#  ('then', 1),
#  ('congestion', 1),
#  ('tough', 1),
#  ('umbrellas', 1),
#  ('less', 1),
#  ('58', 1),
#  ('degrees', 1),
#  ('t', 1),
#  ('Have', 1),
#  ('appliances', 1),
#  ('thrown', 1),
#  ('doing', 1),
#  ('requests', 1),
#  ('E-Waste', 1),
#  ('pickup', 1),
#  ('Staten', 1),
#  ('Island', 1),
#  ('Western', 1),
#  ('https://t.co/eS7aO8J6JW', 1),
#  ('https://t.co/SXGtSgjWCK', 1),
#  ('again', 1),
#  ('https://t.co/dw2BVPvKic', 1),
#  ('https://t.co/hatsAyg1Ki', 1),
#  ('https://t.co/u48X1t525Y', 1),
#  ('https://t.co/ucF03xqm3N', 1),
#  ('move', 1),
#  ('https://t.co/0rZtdhU83C', 1),
#  ('return', 1),
#  ('yard', 1),
#  ('alternative', 1),
#  ('https://t.co/i4mEL4DpPy', 1),
#  ('https://t.co/RPsqZzAboX', 1),
#  ('https://t.co/nx73qfZcSl', 1),
#  ('https://t.co/GMZk9xVu7c', 1),
#  ('performed', 1),
#  ('https://t.co/PKeitMd3xD', 1),
#  ('perform', 1),
#  ('https://t.co/BEICmJ4P4u', 1),
#  ('#bluesky', 1),
#  ('https://t.co/fneUTXwpTr', 1),
#  ('Transformer', 1),
#  ('determined', 1),
#  ('non-suspicious', 1),
#  ('equipment', 1),
#  ('due', 1),
#  ('32', 1),
#  ('nd', 1),
#  ('evening', 1),
#  ('tra', 1),
#  ('https://t.co/DvfiWfiEAQ', 1),
#  ('Ya', 1),
#  ('regresando', 1),
#  ('la', 1),
#  ('el', 1),
#  ('aeropuerto', 1),
#  ('de', 1),
#  ('Guardia', 1),
#  ('pero', 1),
#  ('esperan', 1),
#  ('retrasos', 1),
#  ('evaluando', 1),
#  ('cortes', 1),
#  ('eléctricos', 1),
#  ('Lo', 1),
#  ('sabemos', 1),
#  ('vio', 1),
#  ('fue', 1),
#  ('causada', 1),
#  ('por', 1),
#  ('una', 1),
#  ('descarga', 1),
#  ('eléctrica', 1),
#  ('hay', 1),
#  ('incendios', 1),
#  ('este', 1),
#  ('momento', 1),
#  ('ni', 1),
#  ('heridos', 1),
#  ('Confirming', 1),
#  ('#Astoria', 1),
#  ('result', 1),
#  ('evidence', 1),
#  ('extraterrestrial', 1),
#  ('ac', 1),
#  ('Q66', 1),
#  ('111', 1),
#  ('Q48', 1),
#  ('Use', 1),
#  ('BusTime', 1),
#  ('app', 1),
#  ('check', 1),
#  ('arrival', 1),
#  ('times', 1),
#  ('scheduled', 1),
#  ('https://t.co/LhqJ9vnqS6', 1),
#  ('https://t.co/UEqOulK3PO', 1),
#  ('involved', 1),
#  ('transformers', 1),
#  ('tran', 1),
#  ('Bronx-bound', 1),
#  ('Due', 1),
#  ('outage', 1),
#  ('partial', 1),
#  ('flight', 1),
#  ('operations', 1),
#  ('Many', 1),
#  ('flights', 1),
#  ('departing', 1),
#  ('What', 1),
#  ('Light', 1),
#  ('surge', 1),
#  ('current', 1),
#  ('https://t.co/uJhnDFU7su', 1),
#  ('@NYPDChiefofDept', 1),
#  ('#ConEd', 1),
#  ('#Queens', 1),
#  ('under', 1),
#  ('control', 1),
#  ('time', 1),
#  ('https', 1),
#  ('#FDNY', 1),
#  ('location', 1),
#  ('Department', 1),
#  ('received', 1),
#  ('numerous', 1),
#  ('calls', 1),
#  ('FDNY', 1),
#  ('apparent', 1),
#  ('lit', 1),
#  ('sk', 1),
#  ('https://t.co/siazeNxzx4', 1),
#  ('https://t.co/6mwmsxqYQb', 1),
#  ('Investigating', 1),
#  ('East', 1),
#  ('@NotifyNYC', 1),
#  ('presence', 1),
#  ('emergency', 1),
#  ('personnel', 1),
#  ('Consider', 1),
#  ('alternate', 1),
#  ('rout', 1),
#  ('ADVISORY', 1),
#  ('lights', 1),
#  ('appear', 1),
#  ('been', 1),
#  ('https://t.co/PrQ1VusFg4', 1),
#  ('elevator', 1),
#  ('extra', 1),
#  ('care', 1),
#  ('outdoors', 1),
#  ('public', 1),
#  ('transit', 1),
#  ('whenever', 1),
#  ('possible', 1),
#  ('https://t.co/Jw0sxzgmNB', 1),
#  ('https://t.co/dRHUjeDhQS', 1),
#  ('issued', 1),
#  ('wind', 1),
#  ('during', 1),
#  ('morning', 1),
#  ('commute', 1),
#  ('throughou', 1),
#  ('https://t.co/RbldCCMmnC', 1),
#  ('Bklyn', 1),
#  ('https://t.co/fGNgrgzEk1', 1),
#  ('Times', 1),
#  ('Your', 1),
#  ('Local', 1),
#  ('initiative', 1),
#  ('selects', 1),
#  ('neighborhood', 1),
#  ('businesses', 1),
#  ('grant', 1),
#  ('awards', 1),
#  ('expert', 1),
#  ('advice', 1),
#  ('https://t.co/8ZEa0Wm1xc', 1),
#  ('@NYC_SBS', 1),
#  ('#SmallBusinesses', 1),
#  ('https://t.co/ge70hWlUZ1', 1),
#  ('@nycemergencymgt', 1),
#  ('Management', 1),
#  ('Issues', 1),
#  ('Travel', 1),
#  ('Advisory', 1),
#  ('Read', 1),
#  ('https://t.co/Yk1537iaJz', 1),
#  ('ongoing', 1),
#  ('Planned', 1),
#  ('Work', 1),
#  ('53', 1),
#  ('tube', 1),
#  ('https://t.co/vhZQ2kZ2vb', 1),
#  ('Those', 1),
#  ('needing', 1),
#  ('rid', 1),
#  ('plastic', 1),
#  ('metal', 1),
#  ('fake', 1),
#  ('selling', 1),
#  ('donating', 1),
#  ('Donation', 1),
#  ('opportunities', 1),
#  ('may', 1),
#  ('https://t.co/QtYWhiS7ie', 1),
#  ('Veterans', 1),
#  ('Luke', 1),
#  ('Gasparre', 1),
#  ('gave', 1),
#  ('country', 1),
#  ('@NYCVeterans', 1),
#  ('working', 1),
#  ('sure', 1),
#  ('serve', 1),
#  ('@CourseReport', 1),
#  ('#codingbootcamp', 1),
#  ('opening', 1),
#  ('@Yale', 1),
#  ('@YaleSummer', 1),
#  ('offer', 1),
#  ('week', 1),
#  ('course', 1),
#  ('Summ', 1),
#  ('normal', 1),
#  ('https://t.co/1y4zmNsJ1c', 1),
#  ('Looking', 1),
#  ('homeless', 1),
#  ('@NYCHRA', 1),
#  ('asking', 1),
#  ('HOPE', 1),
#  ('sleeping', 1),
#  ('Monday', 1),
#  ('Jan', 1),
#  ('28', 1),
#  ('pm', 1),
#  ('am', 1),
#  ('https://t.co/rzDbXbUVMa', 1),
#  ('https://t.co/wR79jkV6QN', 1),
#  ('https://t.co/lL4aPT3tRW', 1),
#  ('Neck', 1),
#  ('Other', 1),
#  ('remain', 1),
#  ('begin', 1),
#  ('annual', 1),
#  ('Collection', 1),
#  ('runs', 1),
#  ('permitting', 1),
#  ('Prospect', 1),
#  ('Kings', 1),
#  ('Hwy', 1),
#  ('Despite', 1),
#  ('federal', 1),
#  ('government', 1),
#  ('shutdown', 1),
#  ('Medicaid', 1),
#  ('benefits', 1),
#  ('food', 1),
#  ('Supplemental', 1),
#  ('Security', 1),
#  ('Income', 1),
#  ('SSI', 1),
#  ('HIV', 1),
#  ('AIDS', 1),
#  ('Services', 1),
#  ('Administration', 1),
#  ('HASA', 1),
#  ('Programs', 1),
#  ('Cash', 1),
#  ('Assistance', 1),
#  ('still', 1),
#  ('https://t.co/hd7l3y070Y', 1),
#  ('#', 1),
#  ('Coding', 1),
#  ('schools', 1),
#  ('=', 1),
#  ('https://t.co/4CquSAM725', 1),
#  ('Under', 1),
#  ('Law', 1),
#  ('illegal', 1),
#  ('include', 1),
#  ('wants', 1),
#  ('bin', 1),
#  ('https://t.co/roTYigs2tT', 1),
#  ('https://t.co/7qriPCxx1c', 1),
#  ('https://t.co/DZE8ekowEo', 1),
#  ('https://t.co/Sw22JYwvov', 1),
#  ('@BKLYNlibrary', 1),
#  ('offers', 1),
#  ('storytime', 1),
#  ('array', 1),
#  ('languages', 1),
#  ('Check', 1),
#  ('full', 1),
#  ('listing', 1),
#  ('https://t.co/65uoAj3qsu', 1),
#  ('Congratulations', 1),
#  ('proud', 1),
#  ('parents', 1),
#  ('Maria', 1),
#  ('Ivan', 1),
#  ('newborn', 1),
#  ('Alie', 1),
#  ('She', 1),
#  ('born', 1),
#  ('wee', 1),
#  ('hours', 1),
#  ('Dec', 1),
#  ('26', 1),
#  ('Midtown', 1),
#  ('Tunnel', 1),
#  ('little', 1),
#  ('Bridges', 1),
#  ('Tunnels', 1),
#  ('officers', 1),
#  ('Lieut', 1),
#  ('Harry', 1),
#  ('Persad', 1),
#  ('EMT', 1),
#  ('before', 1),
#  ('joining', 1),
#  ('delivery', 1),
#  ('https://t.co/WGqrdYT8pu', 1),
#  ('Canarsie-Rockaway', 1),
#  ('This', 1),
#  ('December', 1),
#  ('grads', 1),
#  ('got', 1),
#  ('jobs', 1),
#  ('During', 1),
#  ("what's", 1),
#  ('suppose', 1),
#  ('slow', 1),
#  ('hiring', 1),
#  ('And', 1),
#  ("we've", 1),
#  ('pretty', 1),
#  ('https://t.co/sAxrsWjfAs', 1),
#  ('https://t.co/ybdOYgtp9w', 1),
#  ('Add', 1),
#  ('volunteering', 1),
#  ('Resolution', 1),
#  ('@NYCSeniors', 1),
#  ("'", 1),
#  ('Friendly', 1),
#  ('Visiting', 1),
#  ('matches', 1),
#  ('adults', 1),
#  ('friendships', 1),
#  ('intergenerational', 1),
#  ('understanding', 1),
#  ('become', 1),
#  ('volunteer', 1),
#  ('https://t.co/BrLEiQt0nB', 1),
#  ('could', 1),
#  ('difference', 1),
#  ('Share', 1),
#  ('ideas', 1),
#  ('opinions', 1),
#  ('Forest', 1),
#  ('Hills', 1),
#  ('needed', 1),
#  ('Kew', 1),
#  ('Gardens-Union', 1),
#  ('https://t.co/skOOuBU9E5', 1),
#  ('https://t.co/GT7Xe7MGhf', 1),
#  ('Union', 1),
#  ('getting', 1),
#  ('@IDNYC', 1),
#  ('card', 1),
#  ('one', 1),
#  ('Resolutions', 1),
#  ('#IDNYC', 1),
#  ('provides', 1),
#  ('exclusive', 1),
#  ('discounts', 1),
#  ('deals', 1),
#  ('entertainment', 1),
#  ('prescription', 1),
#  ('drugs', 1),
#  ('transportation', 1),
#  ('education', 1),
#  ('fitness', 1),
#  ('Apply', 1),
#  ('https://t.co/tHkzAVQPBs', 1),
#  ('https://t.co/BUX5FnClN8', 1),
#  ('Today', 1),
#  ('sunny', 1),
#  ('It', 1),
#  ('looks', 1),
#  ('enjoy', 1),
#  ('break', 1),
#  ('https://t.co/uyjKeelRJs', 1),
#  ('Additional', 1),
#  ('LIRR', 1),
#  ('accommodating', 1),
#  ('MetroCard', 1),
#  ('holders', 1),
#  ('EN', 1),
#  ('Nostrand', 1),
#  ('limited', 1),
#  ('agent', 1),
#  ('courtesy', 1),
#  ('pass', 1),
#  ('continuing', 1),
#  ('swim', 1),
#  ('classes', 1),
#  ('starting', 1),
#  ('Adult', 1),
#  ('lessons', 1),
#  ('offered', 1),
#  ('Saturdays', 1),
#  ('https://t.co/1qoLS3bEXo', 1),
#  ('https://t.co/gJQbtTSiu7', 1),
#  ('https://t.co/VZm1fs4VnK', 1),
#  ('supports', 1),
#  ('safe', 1),
#  ('fair', 1),
#  ('legalization', 1),
#  ('marijuana', 1),
#  ('https://t.co/JNldoCEwi8', 1),
#  ('assisted', 1),
#  ('who', 1),
#  ('https://t.co/krLWDeVhHa', 1),
#  ('https://t.co/zMv7ChoqAr', 1),
#  ('Flushing-Main', 1),
#  ('Barclays', 1),
#  ('https://t.co/UaIZ7Qqsem', 1),
#  ('Franklin', 1),
#  ('https://t.co/0Jlu7SUixR', 1),
#  ('M14', 1),
#  ('https://t.co/HCTgFa1JAf', 1),
#  ('tunnel', 1),
#  ('https://t.co/RcC77Y25TZ', 1),
#  ('Fort', 1),
#  ('Hamilton', 1),
#  ('unsanitary', 1),
#  ('condition', 1),
#  ('179', 1),
#  ('police', 1),
#  ('St-Washington', 1),
#  ('https://t.co/F01ITFfLrF', 1),
#  ('transferring', 1),
#  ('M20', 1),
#  ('teams', 1),
#  ('https://t.co/LtzLS54CP2', 1),
#  ('route', 1),
#  ('assist', 1),
#  ('We', 1),
#  ('re', 1),
#  ('back', 1),
#  ('174', 1),
#  ('175', 1),
#  ('Sts', 1),
#  ('reopened', 1),
#  ('Repaired', 1),
#  ('structural', 1),
#  ('steel', 1),
#  ('concrete', 1),
#  ('Replaced', 1),
#  ('edges', 1),
#  ('stairways', 1),
#  ('Added', 1),
#  ('digital', 1),
#  ('wayfinding', 1),
#  ('screens', 1),
#  ('https://t.co/HAbB7hsePv', 1),
#  ('https://t.co/S6qsdBIm3R', 1),
#  ('@NYCPlanning', 1),
#  ('Director', 1),
#  ('Marisa', 1),
#  ('Lago', 1),
#  ('marked', 1),
#  ('approval', 1),
#  ('Planning', 1),
#  ('Special', 1),
#  ('Permit', 1),
#  ('would', 1),
#  ('order', 1),
#  ('hotels', 1),
#  ('motels', 1),
#  ('light', 1),
#  ('manufacturing', 1),
#  ('districts', 1),
#  ('https://t.co/EuQc34liMi', 1),
#  ('Regular', 1),
#  ('EMS', 1),
#  ...]

# %% [markdown]
# Right so in above output , we see that our punctuation marks and common terms like "the" and "of" etc. are being shown as top terms. The next step is to remove these words to focus on more IMPORTANT words. this step is called the "Stop-word Removal".

# %% [markdown]
# ### Stop Word Removal
#
# Every language has words that are very common. While their use in the language is very important, they do not carry any clear meaning on their own like conjunctions,  adverbs, etc. In the language of NLP , these are referred to as **Stop-words**.
# Stop-word removal is one important step that should be considered during the pre-processing stages. One can build a custom list of stop-words, or use available lists (e.g. [NLTK](https://www.nltk.org/) provides a simple list for English stop-words). You can search Internet for domain specific stop-words as well as some words may carry a deeper meaning in one domain while could be meaningless in another. (Try thinking of a few examples).
#
# Given the nature of our data and our tokenization, we should also be careful with all the punctuation marks and with terms like RT (used for re-tweets), via (used to mention the original author of an article or a re-tweet), ... (used for ongoing tweet) etc. Below is a stop word list that we build from nltk + punctuation + some twitter specific stop words. Your are encouraged to add more to it.

# %%
# Create a stop word list from nltk stopwords, punctuation marks and some twitter specific stop terms
import nltk
from nltk.corpus import stopwords
nltk.download("stopwords")
import string
punctuation = list(string.punctuation)
stop = stopwords.words('english') + punctuation + ['rt', 'RT',  'via', 'The', 'the', '…', '¡', 'and', 'at', 'are', 'with', 'to', '.', 'of', ':']
print(stop)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\rrubel\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't", '!', '"', '#', '$', '%', '&', "'", '(', ')', '*', '+', ',', '-', '.', '/', ':', ';', '<', '=', '>', '?', '@', '[', '\\', ']', '^', '_', '`', '{', '|', '}', '~', 'rt', 'RT', 'via', 'The', 'the', '…', '¡', 'and', 'at', 'are', 'with', 'to', '.', 'of', ':']

# %% [markdown]
# Now we can simply use this list to clean up our tweets. Perform following tasks
# * Clear count_all to start a new counter
# * Change the routine above to collect tweets while filtering with above stop word list.
# * Use list comprehension to only include terms NOT found in the stop-word list
# * Print the top ten most common terms.

# %%
# Calculate term frequencies

cnt = Counter()
for tweet in data:
    i = preprocess_tweet(tweet['full_text'])
    for z in list(range(0, len(i))):
        if i[z] not in stop:
            cnt[i[z]] += 1
cnt.most_common(10)

    
# [('Vote', 35), ('#ODSCWest', 29), ('Data', 26), ('#ODSC', 21), ('#DataScience', 18), 
# ('’', 16), ('AI', 16), ('#AI', 14), ('@ODSC', 13), ('data', 12)]
# Out:
# [('trains', 104),
#  ('train', 82),
#  ('St', 75),
#  ('service', 74),
#  ('Av', 66),
#  ('delays', 56),
#  ('resumed', 38),
#  ('running', 33),
#  ('2', 32),
#  ('Northbound', 27)]

# %% [markdown]
# So this looks much better, still not perfect though. Remember this is an iterative process and you would want to refine your stop word list. Here we see some useful terms like commonly mentioned hashtags etc. with lots of unwanted terms that xcould be included as stop words. Do some survey on other stop-word lists available online and include them with you own criteria.

# %% [markdown]
# ## More Term Filtering
#
# Besides stop-word removal, we can further customize the list of terms we are interested in.
#
# ### Calculate Document  Frequency
#
# > The number of documents in the collection that contain a term t.
#
# We can also calculate document frequency which shows us the number of documents (tweets) that show a specific term. For this we can make small tweaks to the code we used to calculate all terms frequencies for all document. Here we shall count every term only once in every document and see how many documents contain a specific term. For this you need to clear the counter, and perform following tasks for every tweet.
#
# * Calculate frequencies for all terms while filtering out the stop words
# * Make a set of unique terms (counted only once) for each tweet
# * Update the counter
#
# * Show the top 20 terms from the counter

# %%
# Calculate document frequencies

cnt = Counter()
for tweet in data:
    count = Counter()
    i = preprocess_tweet(tweet['full_text'])
    for z1 in list(range(0, len(i))):
            count[i[z1]] += 1
    new_list = list(count.keys())
    for z2 in list(range(0, len(new_list))):
        if i[z2] not in stop:
            cnt[i[z2]] += 1
cnt.most_common(10)
        


# [('#ODSCWest', 29), ('Data', 24), ('#ODSC', 21), ('#DataScience', 18), ('’', 14), 
# ('AI', 14), ('#AI', 14), ('@ODSC', 13), ('data', 12), ('Science', 11), ('A', 11), ('2018', 11), 
# ('West', 11), ('3', 9), ('amp', 9), ('Join', 8), ('Nov', 8), ('How', 8), ('#bordercollie', 8), ('Python', 7)]
# Out:
# [('trains', 98),
#  ('train', 75),
#  ('St', 72),
#  ('service', 68),
#  ('Av', 55),
#  ('delays', 54),
#  ('resumed', 38),
#  ('running', 32),
#  ('Northbound', 27),
#  ('Southbound', 25)]

# %% [markdown]
# Do you see any improvements in results ? You may need to work more on the stop word list and maybe filter out the numerical terms like dates and other numbers. You could also filter out terms with length less than a set threshold e.g. only include terms that carry 4 or more characters. Like we saw earlier, it is an iterative process and we may have to revisit our parsing code a few times to get more meaningful answers.
#
# ### Calculate Hashtag Frequencies
#
# A Hashtag in a tweet is just another term , identified by a hash (#) sign. Let's iterate through our corpus of tweets again collecting all terms that are hashtags i.e. start with a #. Perform following tasks for each tweet:
# * Reset the counter
# * Collect the terms starting with # sign
# * Update the counter
# * List and visualize top 20 hashtags as bar charts and label properly

# %%
# Calculte top 20 hashtags

# Plot top 20 hashtags

cnt = Counter()
for tweet in data:
    i = preprocess_tweet(tweet['full_text'])
    for z in list(range(0, len(i))):
        if i[z] not in stop:
            if i[z][0] == '#':
                cnt[i[z][1:]] += 1
cnt.most_common(20)  

# [('#ODSCWest', 29), ('#ODSC', 21), ('#DataScience', 18), ('#AI', 14), ('#bordercollie', 8), 
# ('#', 6), ('#abdsc', 4), ('#BigData', 4), ('#MachineLearning', 4), ('#datascience', 4), 
# ('#BorderCollie', 4), ('#DeepLearning', 2), ('#Python', 2), ('#puppy', 2), ('#dogs', 2), 
#('#dogsoftwitter', 2), ('#collie', 2), ('#earlyvote', 2), ('#TeamAbrams', 1), ('#GAGov', 1)]
# Out:
# [('OneNYC', 2),
#  ('bluesky', 1),
#  ('Astoria', 1),
#  ('ConEd', 1),
#  ('Queens', 1),
#  ('FDNY', 1),
#  ('SmallBusinesses', 1),
#  ('codingbootcamp', 1),
#  ('IDNYC', 1),
#  ('100daysofcode', 1),
#  ('NYCHA', 1),
#  ('Brooklyn', 1),
#  ('Bronx', 1),
#  ('NYCstreets', 1),
#  ('Mulchfest', 1),
#  ('wellnesswednesday', 1)]

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(12,5))
graph_list = dict(cnt.most_common(20))
plt.bar(range(len(graph_list)), list(graph_list.values()), align='center')
plt.xticks(range(len(graph_list)), list(graph_list.keys()), rotation='vertical')
plt.xlabel("Hashtags")
plt.ylabel("Count")
plt.title("Hashtag by Count from Tweets on my Feed")
# Out:
# Text(0.5,1,'Hashtag by Count from Tweets on my Feed')

# %% [markdown]
# ### Calculate Bi-gram Frequencies
#
# While the frequent terms post cleaning, stop removal etc. represent a clear topic, simple term frequencies don’t give us a deeper explanation of what the text is about. To put things in context, let’s consider sequences of two terms combined (a.k.a. bigrams).
#
# > **A bigram is a sequence of two adjacent elements from a string of tokens, which are typically letters, syllables, or words. A bigram is an n-gram for n=2. The frequency distribution of every bigram in a string is commonly used for simple statistical analysis of text in many applications, including in computational linguistics, cryptography, speech recognition, and so on.**(wiki)
#
# We can import bigrams function from nltk library to automatically create bigrams from a given sequence of text. Here is a quick demo:

# %%
from nltk import bigrams 

text = 'This is a very simple sentence'
terms = [term for term in preprocess_tweet(text)]
terms_bigram = bigrams(terms)
list(terms_bigram)
# Out:
# [('This', 'is'),
#  ('is', 'a'),
#  ('a', 'very'),
#  ('very', 'simple'),
#  ('simple', 'sentence')]

# %% [markdown]
# The combination of two words may help get the deeper understanding of the tweet. You could also calculate trigrams or even higher , but it might get computationally expensive.
#
# You are required to calculate the frequencies of bigrams in the collected tweets, and find the most frequent combination of two adjacent elements. Perform following tasks:
#
# * Clear the counter
# * Collect all the terms excluding stop words, hashtags and mentions
# * Calculte the bigrams for each tweet and update counter with frequencies
# * Display and top 20 bigrams

# %%
# Show the frequency of top 20 bigrams in the corpus

cnt = Counter()
for tweet in data:

    new_list = []
    i = preprocess_tweet(tweet['full_text'])
    for word in i:
        if word not in stop:
            new_list.append(word)
    terms_bigram = list(bigrams(new_list))
    
    for count in list(range(0,len(terms_bigram))):
        cnt[terms_bigram[count]] += 1
        
cnt.most_common(20)


# [(('Vote', 'Vote'), 33), (('Data', 'Science'), 11), (('San', 'Francisco'), 7), 
# (('West', '2018'), 7), (('Oct', '31'), 5), (('31', 'Nov'), 5), (('Nov', '3'), 5), 
# (('Don', '’'), 4), (('Francisco', 'Oct'), 4), (('Big', 'Data'), 4), (('machine', 'learning'), 3), 
# (('data', 'scientists'), 3), (('data', 'science'), 3), (('Machine', 'Learning'), 3), 
# (('Deep', 'Learning'), 3), (('Data', 'Scientist'), 3), (('LIVESTREAM', 'Pass'), 3), 
# (('I', '’'), 3), (('\u2066', '\u2069'), 3), (('Cheat', 'Sheet'), 2)]
# Out:
# [(('train', 'service'), 43),
#  (('trains', 'running'), 32),
#  (('service', 'resumed'), 25),
#  (('running', 'delays'), 23),
#  (('trains', 'delayed'), 17),
#  (('resumed', 'delays'), 17),
#  (('trains', 'resumed'), 13),
#  (('L', 'trains'), 13),
#  (('3', 'trains'), 11),
#  (('train', 'mechanical'), 11),
#  (('resumed', 'making'), 10),
#  (('mechanical', 'problems'), 10),
#  (('For', 'service'), 10),
#  (('problems', 'service'), 9),
#  (('Q', 'trains'), 9),
#  (('1', 'Av'), 9),
#  (('23', 'St'), 9),
#  (('track', 'maintenance'), 9),
#  (('Coney', 'Island-Stillwell'), 9),
#  (('1', '2'), 9)]

# %%
plt.figure(figsize=(12,5))
graph_list = dict(cnt.most_common(20))
plt.bar(range(len(graph_list)), list(graph_list.values()), align='center')
plt.xticks(range(len(graph_list)), list(graph_list.keys()), rotation='vertical')
plt.xlabel("Bigrams")
plt.ylabel("Count")
plt.title("Most Common Bigrams from Tweets on my Feed")
# Out:
# Text(0.5,1,'Most Common Bigrams from Tweets on my Feed')

# %% [markdown]
# So we start to see something a bit more meaningful. For this case, we see more meaningul combinations of words which clearly indicate themes or recurring topics within tweets. A bit more effort can really get us results that can be easily analyzed to get some real insights.

# %% [markdown]
# ## Collecting Tweets From A User's Timeline - `user_timeline()` method
#
#
# For some analyses, you may be interested in collecting tweets from someone else's timeline. We can use `user_timeline()` method to achieve this while passing `id=name` parameter to identify the user. Let's collect last 100 tweets from "FlatironSchool" and visualize top 10 hashtags and mentions. Apart from the new method `user_timeline()`, everything else will remain the same as above. Perform following tasks:
#
# * Collect last 200 tweets from "FlatironSchool"
# * Calculate top 10 hashtags and mentions as terms from collected tweets
# * Visualize results as bargraphs in both cases

# %%
# Calculate and Visulize top 10 hashtags in last 200 tweets from FlatironSchool's Timeline
flat = my_first_api.user_timeline(id='FlatironSchool',count=100, tweet_mode='extended')
cnt = Counter()
for tweet in flat:
    i = preprocess_tweet(tweet.full_text)
    for z in list(range(0, len(i))):
        if i[z] not in stop:
            if i[z][0] == '#':
                cnt[i[z][1:]] += 1
cnt.most_common(10)
# Out:
# [('100DaysOfCode', 6),
#  ('flatironatlanta', 2),
#  ('flatironseattle', 2),
#  ('bettertogether', 2),
#  ('codingbootcamp', 1),
#  ('100daysofcode', 1),
#  ('wellnesswednesday', 1),
#  ('alum', 1),
#  ('christmaseve', 1),
#  ('mickeymouse', 1)]

# %%
plt.figure(figsize=(12,5))
graph_list = dict(cnt.most_common(10))
plt.bar(range(len(graph_list)), list(graph_list.values()), align='center')
plt.xticks(range(len(graph_list)), list(graph_list.keys()), rotation='vertical')
plt.xlabel("Hashtags")
plt.ylabel("Count")
plt.title("Hashtag by Count from Flatiron Tweets")
# Out:
# Text(0.5,1,'Hashtag by Count from Flatiron Tweets')

# %%
# Calculate and Visulize top 10 mentions in last 200 tweets from FlatironSchool's Timeline 
# Exclude @FlatironSchool mentions 
cnt = Counter()
for tweet in flat:
    i = preprocess_tweet(tweet.full_text)
    for z in list(range(0, len(i))):
        if i[z] not in stop:
            if i[z][0] == '@' and i[z][1:] != 'FlatironSchool':
                cnt[i[z][1:]] += 1
cnt.most_common(10)
# Out:
# [('aviflombaum', 10),
#  ('WeWork', 6),
#  ('ValeriaRagonese', 6),
#  ('BekahHW', 5),
#  ('meisuleen', 4),
#  ('ctosummit', 4),
#  ('designationio', 3),
#  ('doneil155', 3),
#  ('hahaha_it_is_i', 3),
#  ('Rosenberg1Shari', 3)]

# %%
plt.figure(figsize=(10,5))
graph_list = dict(cnt.most_common(10))
plt.bar(range(len(graph_list)), list(graph_list.values()), align='center')
plt.xticks(range(len(graph_list)), list(graph_list.keys()), rotation='vertical')
plt.xlabel("Mentions")
plt.ylabel("Count")
plt.title("Mentions by Count from Flatiron Tweets")
# Out:
# Text(0.5,1,'Mentions by Count from Flatiron Tweets')

# %% [markdown]
# ## Collecting Tweets Using a Keyword -  `.search()` method
#
# Let’s look at one last use case i.e. getting the most recent tweets that contain a specific keyword. This can be extremely useful if you want to monitor specifically mentioned topics in the Twitter world, or even to see how your business is getting mentioned. We shall use Twitter standard serach API whith `q=query` parameter to pass our search query.
#
# Let’s say we want to see how FlatironSchool is being been mentioned on Twitter. We would like to see which Twitter  users are being mentioned in conjunction with FlatironSchool. Remember maxiumum number of tweets you can mine is 180 per 15 minutes window.
#
# Perform following tasks
# * Clear the counter
# * Collect 200 tweets that mention Flatiron School using `.search()` method. (Use `language=en` to collect english tweets only)
# * Collect the top 30 @mentions from the all tweets that mention FlatironSchool.
# * Visualize the results as a wordcloud

# %%
# The search term you want to find
query = "FlatironSchool"
# Language code (follows ISO 639-1 standards)
language = "en"
tweetCount = 200

search = my_first_api.search(q=query,count=200, language = "en", tweet_mode='extended')
cnt = Counter()
for tweet in search:
    t = tweet._json['full_text']
    i = preprocess_tweet(t)
    for z in list(range(0, len(i))):
        if i[z] not in stop:
            if i[z][0] == '@':
                cnt[i[z][1:]] += 1
cnt.most_common(30)

# [('@FlatironSchool', 83), ('@fulmolightning', 52), ('@pierre_rochard', 21), 
# ('@peterktodd', 19), ('@MsJisola', 17), ('@ElectrumWallet', 17), ('@BtcpayServer', 14), 
# ('@r0ckstardev', 13), ('@Blockstream', 12), ('@Excellion', 12), ('@rootzoll', 11), 
# ('@CryptoCloaks', 8), ('@CasaHODL', 7), ('@overtorment', 6), ('@CReckhow', 5), 
# ('@starkness', 4), ('@CodeNewbies', 4), ('@TeachFirst', 4), ('@jeetsidhu_', 3), ('@Snyke', 3)]
# Out:
# [('FlatironSchool', 66),
#  ('aviflombaum', 14),
#  ('marilynika', 12),
#  ('LondonGeekettes', 12),
#  ('debs_obrien', 12),
#  ('todopatterson', 12),
#  ('OpenClassrooms', 12),
#  ('treehouse', 12),
#  ('SomeHats', 12),
#  ('EraseAllKittens', 12),
#  ('ArmaniLab', 12),
#  ('USC', 12),
#  ('ValeriaRagonese', 10),
#  ('meisuleen', 9),
#  ('WebDevTez', 9),
#  ('rails', 8),
#  ('andrs', 7),
#  ('mary_grace', 7),
#  ('community_pulse', 7),
#  ('MHPrompt', 7),
#  ('callmelisaj', 7),
#  ('robynexton', 7),
#  ('HerSocialApp', 7),
#  ('JennySnapTech', 7),
#  ('SnapFashion', 7),
#  ('SnapTech', 7),
#  ('Forbes', 7),
#  ('hazel_moore', 7),
#  ('furkankarayel', 7),
#  ('diversein', 7)]

# %% [markdown]
# Another common way to view dominant terms in a corpus of text is to visualize a wordcloud of top n terms. Here is an API reference for [WordCloud for Python](https://amueller.github.io/word_cloud/references.html).
# * Create a word cloud from top 20 mentions above to highlight who is being mentioned most.

# %%
# Visualize the word cloud for top 20 mentions everytime flatiron school gets mentioned in a tweet
# !pip install wordcloud
import numpy as np
from PIL import Image
from os import path
import wordcloud
from wordcloud import WordCloud
mask = np.array(Image.open("FS.png"))
cloud = wordcloud.WordCloud(max_font_size=35, max_words=100, background_color="white")

cloud.generate_from_frequencies(dict(cnt.most_common(10)))

plt.figure(figsize=(15,10))
plt.imshow(cloud, interpolation="bilinear")
plt.axis("off")
plt.show()
# Out:
# Requirement already satisfied: wordcloud in c:\users\rrubel\appdata\local\continuum\anaconda3\lib\site-packages (1.5.0)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\rrubel\appdata\local\continuum\anaconda3\lib\site-packages (from wordcloud) (1.15.1)
# Requirement already satisfied: pillow in c:\users\rrubel\appdata\local\continuum\anaconda3\lib\site-packages (from wordcloud) (5.2.0)

# %% [markdown]
# This looks great. Try collecting a large number of tweets using the cfietria seen previously and create a more populated word cloud. You can also customize and prettify it to your heart's content.
#
# ## From JSON to DataFrames
#
# So far, we have been processing our tweets directly from the JSON files. It may be desired for an advanced analystical experiment to store data as pandas dataframe and enjoy all the goodness of pandas, scikitlearn and buult in statistics. Let's try to select some selected parts of the tweet and save it nicely as pandas dataframe and csv file.
#
# #### Load `tweets.json`  and save following contents as pandas dataframe `tweet_json_df`
#     * id
#     * full_text
#     * favorite_count
#     * retweet_count
#     * created_at
#
# * Set some meaningful names for dataframe columns to store these values.
# * Print the dataframe head to inspect the contents
# * save data as "tweets.csv"

# %%
# Parse the JSON file, selecting above attributes for each tweet and saving as a new row in a pandas dataframe
import pandas as pd

with open('tweets.json', encoding='utf-8') as json_file:  
    data = json.load(json_file)
df = pd.DataFrame(data)
df = df[['id','full_text','favorite_count','retweet_count','created_at']]
df.head()
df.to_csv('final_tweets_df.csv')

# tweet_id	             text	                                         favorite_count	retweet_count	created_at
# 0	1056647627062661121	RT @RalstonReports: The turnout models are loo...	0	15	Sun Oct 28 20:43:20 +0000 2018
# 1	1056647041093373952	[Cheat Sheet] Python Basics For Data Science h...	2	1	Sun Oct 28 20:41:00 +0000 2018
# 2	1056640802401615872	RT @Popehat: NYT: Well, Okay, But Are People ...	0	620	Sun Oct 28 20:16:13 +0000 2018
# 3	1056639940438544384	https://t.co/txeJ3g9IMW	1	1	Sun Oct 28 20:12:47 +0000 2018
# 4	1056638994203729922	IBM and NVIDIA collaborate to expand machine l...	3	1	Sun Oct 28 20:09:02 +0000 2018

# %% [markdown]
# So there we have it. The skills that you have learned in this lab can be used towards data journalism, data science related articles etc. These skills will also come in handy for more advanced NLP techniques like topic modelling, sentiment analysis, emoticon analysis etc.

# %% [markdown]
# ## Level Up - Optional
#
# * Try generating more wordclouds from all the examples we saw in this lab.
# * Ask yourself an analytical question and mine Twitter to get tweets, process them in tweepy and visualize the results.
# * Count emoticons for smily face, frowning face, excited face etc. and see what are people's sentiments about a specific topic of interest i.e. Brexit, War in Syria, Best actor from last Oscars etc.
# * See which Twitter member is mentioning you the most at Twitter.
# * ON-going : Repeatedly mine twitter (say once per day) on a topic of interest and collect,parse,visualize tweets to see any changing trends.

# %% [markdown]
# ## Further Reading
#
# * [Introduction to NLP](https://blog.algorithmia.com/introduction-natural-language-processing-nlp/)
# * [Python/NLTK Language Processing](http://blog.chapagain.com.np/python-nltk-twitter-sentiment-analysis-natural-language-processing-nlp/)
# * [Applying NLP to Twitter in Python](https://dzone.com/articles/applying-nlp-to-tweets-with-python)
# * [Using the Twitter API and NLP to analyze the tweets of different users.](https://towardsdatascience.com/twitter-api-and-nlp-7a386758eb31)

# %% [markdown]
# ## Summary
#
# In this lab, we saw how to collect data from twitter using OAuth and collect Tweets under for a number of different use cases. We looked at parsing the JSON file for collecting relevant information and also visualized the outcome of our processing. As a reminder, this lab is supposed to be a data engineering oriented lab, i.e. getting data ready for processing. We shall see more on NLP later in next module of the course. This lab should get you all ready for some serious experiments like sentiment analysis , predictions and classification tasks.
